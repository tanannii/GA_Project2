# %% [markdown]
# # 1. Importing Datasets/Libraries

# %%
#Importing libraries
import pandas as pd
import matplotlib.pyplot as plt
import missingno as msno
import seaborn as sns
import numpy as np
#sns.set_style('darkgrid')
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

from sklearn.linear_model import LinearRegression, LassoCV, RidgeCV, ElasticNetCV
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict, GridSearchCV
from sklearn.preprocessing import PolynomialFeatures, PowerTransformer, StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score, mean_squared_error

# %%
#change wd
import os
os.chdir("C:/Users/annitan/Desktop/GA/DSIF-SG-7 - Copy/Project_2/datasets")

# %%
#importing datasets
#import train and test
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')


#Change columns names to lowercase
train.columns = train.columns.str.lower().str.replace(' ', '_')
test.columns = test.columns.str.lower().str.replace(' ', '_')

# %% [markdown]
# # 2. Cleaning of data - train set

# %% [markdown]
# ## 2.1 Understanding Columns

# %%
# Check the shape of data set
print(f'shape of train set: {train.shape}')
# Out:
# shape of train set: (2051, 81)

# %%
# Check datatypes and numbers of non-null values; for train
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2051 entries, 0 to 2050
# Data columns (total 81 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               2051 non-null   int64
#  1   pid              2051 non-null   int64
#  2   ms_subclass      2051 non-null   int64
#  3   ms_zoning        2051 non-null   object
#  4   lot_frontage     1721 non-null   float64
#  5   lot_area         2051 non-null   int64
#  6   street           2051 non-null   object
#  7   alley            140 non-null    object
#  8   lot_shape        2051 non-null   object
#  9   land_contour     2051 non-null   object
#  10  utilities        2051 non-null   object
#  11  lot_config       2051 non-null   object
#  12  land_slope       2051 non-null   object
#  13  neighborhood     2051 non-null   object
#  14  condition_1      2051 non-null   object
#  15  condition_2      2051 non-null   object
#  16  bldg_type        2051 non-null   object
#  17  house_style      2051 non-null   object
#  18  overall_qual     2051 non-null   int64
#  19  overall_cond     2051 non-null   int64
#  20  year_built       2051 non-null   int64
#  21  year_remod/add   2051 non-null   int64
#  22  roof_style       2051 non-null   object
#  23  roof_matl        2051 non-null   object
#  24  exterior_1st     2051 non-null   object
#  25  exterior_2nd     2051 non-null   object
#  26  mas_vnr_type     2029 non-null   object
#  27  mas_vnr_area     2029 non-null   float64
#  28  exter_qual       2051 non-null   object
#  29  exter_cond       2051 non-null   object
#  30  foundation       2051 non-null   object
#  31  bsmt_qual        1996 non-null   object
#  32  bsmt_cond        1996 non-null   object
#  33  bsmt_exposure    1993 non-null   object
#  34  bsmtfin_type_1   1996 non-null   object
#  35  bsmtfin_sf_1     2050 non-null   float64
#  36  bsmtfin_type_2   1995 non-null   object
#  37  bsmtfin_sf_2     2050 non-null   float64
#  38  bsmt_unf_sf      2050 non-null   float64
#  39  total_bsmt_sf    2050 non-null   float64
#  40  heating          2051 non-null   object
#  41  heating_qc       2051 non-null   object
#  42  central_air      2051 non-null   object
#  43  electrical       2051 non-null   object
#  44  1st_flr_sf       2051 non-null   int64
#  45  2nd_flr_sf       2051 non-null   int64
#  46  low_qual_fin_sf  2051 non-null   int64
#  47  gr_liv_area      2051 non-null   int64
#  48  bsmt_full_bath   2049 non-null   float64
#  49  bsmt_half_bath   2049 non-null   float64
#  50  full_bath        2051 non-null   int64
#  51  half_bath        2051 non-null   int64
#  52  bedroom_abvgr    2051 non-null   int64
#  53  kitchen_abvgr    2051 non-null   int64
#  54  kitchen_qual     2051 non-null   object
#  55  totrms_abvgrd    2051 non-null   int64
#  56  functional       2051 non-null   object
#  57  fireplaces       2051 non-null   int64
#  58  fireplace_qu     1051 non-null   object
#  59  garage_type      1938 non-null   object
#  60  garage_yr_blt    1937 non-null   float64
#  61  garage_finish    1937 non-null   object
#  62  garage_cars      2050 non-null   float64
#  63  garage_area      2050 non-null   float64
#  64  garage_qual      1937 non-null   object
#  65  garage_cond      1937 non-null   object
#  66  paved_drive      2051 non-null   object
#  67  wood_deck_sf     2051 non-null   int64
#  68  open_porch_sf    2051 non-null   int64
#  69  enclosed_porch   2051 non-null   int64
#  70  3ssn_porch       2051 non-null   int64
#  71  screen_porch     2051 non-null   int64
#  72  pool_area        2051 non-null   int64
#  73  pool_qc          9 non-null      object
#  74  fence            400 non-null    object
#  75  misc_feature     65 non-null     object
#  76  misc_val         2051 non-null   int64
#  77  mo_sold          2051 non-null   int64
#  78  yr_sold          2051 non-null   int64
#  79  sale_type        2051 non-null   object
#  80  saleprice        2051 non-null   int64
# dtypes: float64(11), int64(28), object(42)
# memory usage: 1.3+ MB

# %%
#Drop 'Id' and 'PID'. Not needed. 
train = train.drop(['id','pid'],axis=1)
# Check the shape of data set
print(f'shape of train set: {train.shape}')
# Out:
# shape of train set: (2051, 79)

# %%
#Change data type to string
train["ms_subclass"]=train["ms_subclass"].astype('str')

# %% [markdown]
# ## 2.2 Null Values

# %% [markdown]
# ### 2.2.1 Checking which columns has Null Values

# %%
#Check for null, sorted; train data set
train.isnull().sum().sort_values(ascending=False)
# Out:
# pool_qc            2042
# misc_feature       1986
# alley              1911
# fence              1651
# fireplace_qu       1000
# lot_frontage        330
# garage_finish       114
# garage_qual         114
# garage_yr_blt       114
# garage_cond         114
# garage_type         113
# bsmt_exposure        58
# bsmtfin_type_2       56
# bsmt_cond            55
# bsmt_qual            55
# bsmtfin_type_1       55
# mas_vnr_area         22
# mas_vnr_type         22
# bsmt_full_bath        2
# bsmt_half_bath        2
# garage_area           1
# garage_cars           1
# total_bsmt_sf         1
# bsmt_unf_sf           1
# bsmtfin_sf_2          1
# bsmtfin_sf_1          1
# 3ssn_porch            0
# screen_porch          0
# full_bath             0
# half_bath             0
# bedroom_abvgr         0
# kitchen_abvgr         0
# kitchen_qual          0
# totrms_abvgrd         0
# functional            0
# paved_drive           0
# wood_deck_sf          0
# open_porch_sf         0
# sale_type             0
# enclosed_porch        0
# yr_sold               0
# mo_sold               0
# misc_val              0
# pool_area             0
# fireplaces            0
# ms_subclass           0
# heating_qc            0
# gr_liv_area           0
# low_qual_fin_sf       0
# lot_area              0
# street                0
# lot_shape             0
# land_contour          0
# utilities             0
# lot_config            0
# land_slope            0
# neighborhood          0
# condition_1           0
# condition_2           0
# bldg_type             0
# house_style           0
# overall_qual          0
# overall_cond          0
# year_built            0
# year_remod/add        0
# roof_style            0
# roof_matl             0
# exterior_1st          0
# exterior_2nd          0
# exter_qual            0
# exter_cond            0
# foundation            0
# heating               0
# ms_zoning             0
# central_air           0
# electrical            0
# 1st_flr_sf            0
# 2nd_flr_sf            0
# saleprice             0
# dtype: int64

# %%
#Drop columns with >= 1000 missing data (almost 50%)
#columns=['pool_qc','misc_feature','alley','fence','fireplace_qu']
train.drop(columns=['pool_qc','misc_feature','alley','fence','fireplace_qu'],axis = 1, inplace=True)
#Check the new shape for train
train.shape
# Out:
# (2051, 74)

# %% [markdown]
# ### 2.2.2 Clean up column 'lot_fontage'

# %%
#LotFrontage: Linear feet of street connected to property
#print(f'Number of missing values in lot_fontage {train['lot_frontage'].isna().sum()}')
rows = train.shape[0]
print(f'Number of missing values in lot_fontage: {train.lot_frontage.isna().sum()}')
print(f'% of missing values in lot_fontage: {round(train.lot_frontage.isna().sum()/rows*100,1)}%')
# Out:
# Number of missing values in lot_fontage: 330
# % of missing values in lot_fontage: 16.1%

# %%
#Look at the value counts
train['lot_frontage'].value_counts()
# Out:
# 60.0     179
# 70.0      96
# 80.0      94
# 50.0      90
# 65.0      71
# 75.0      68
# 85.0      52
# 63.0      38
# 24.0      33
# 78.0      33
# 21.0      32
# 64.0      31
# 90.0      31
# 74.0      31
# 72.0      30
# 68.0      28
# 62.0      28
# 73.0      25
# 100.0     23
# 82.0      21
# 43.0      20
# 57.0      20
# 52.0      20
# 66.0      19
# 79.0      19
# 67.0      18
# 59.0      18
# 53.0      18
# 76.0      16
# 88.0      16
# 51.0      16
# 56.0      15
# 69.0      14
# 84.0      14
# 55.0      14
# 81.0      14
# 40.0      13
# 35.0      13
# 92.0      13
# 91.0      13
# 58.0      13
# 71.0      13
# 44.0      12
# 30.0      11
# 48.0      11
# 41.0      11
# 77.0      11
# 95.0      11
# 34.0      11
# 96.0      11
# 83.0      10
# 61.0      10
# 105.0      9
# 107.0      9
# 93.0       9
# 110.0      9
# 94.0       8
# 45.0       8
# 42.0       8
# 87.0       8
# 120.0      8
# 98.0       7
# 102.0      7
# 86.0       7
# 37.0       6
# 89.0       6
# 54.0       6
# 47.0       6
# 32.0       6
# 103.0      5
# 36.0       5
# 97.0       4
# 38.0       4
# 129.0      4
# 109.0      4
# 114.0      4
# 39.0       4
# 108.0      4
# 99.0       3
# 112.0      3
# 26.0       3
# 106.0      3
# 125.0      3
# 104.0      3
# 128.0      3
# 134.0      3
# 49.0       3
# 46.0       2
# 113.0      2
# 140.0      2
# 130.0      2
# 101.0      2
# 313.0      2
# 124.0      1
# 33.0       1
# 25.0       1
# 153.0      1
# 135.0      1
# 141.0      1
# 144.0      1
# 138.0      1
# 115.0      1
# 200.0      1
# 122.0      1
# 150.0      1
# 121.0      1
# 160.0      1
# 174.0      1
# 155.0      1
# 123.0      1
# 111.0      1
# 116.0      1
# 118.0      1
# 119.0      1
# 117.0      1
# 137.0      1
# 22.0       1
# 195.0      1
# Name: lot_frontage, dtype: int64

# %%
#Understand the data in the column
train['lot_frontage'].describe()
# Out:
# count    1721.000000
# mean       69.055200
# std        23.260653
# min        21.000000
# 25%        58.000000
# 50%        68.000000
# 75%        80.000000
# max       313.000000
# Name: lot_frontage, dtype: float64

# %%
# Group lots by lots configuration; find the mean of their lot_frontage
grouped_lots = train.groupby(['lot_config']).agg({'lot_frontage' : 'mean'})
grouped_lots
#Might be meaningful to replace missing values with mean based on their lot_config
# Out:
#             lot_frontage
# lot_config
# Corner         83.245552
# CulDSac        55.228571
# FR2            60.836735
# FR3            87.000000
# Inside         66.952780

# %%
#replace np.nan with average for lot_config of that type
train.loc[(train['lot_frontage'].isna()) & (train['lot_config'] == 'Corner'), 'lot_frontage'] = 83.25
train.loc[(train['lot_frontage'].isna()) & (train['lot_config'] == 'CulDSac'), 'lot_frontage'] = 54.734375        
train.loc[(train['lot_frontage'].isna()) & (train['lot_config'] == 'FR2'), 'lot_frontage'] = 60.836735        
train.loc[(train['lot_frontage'].isna()) & (train['lot_config'] == 'FR3'), 'lot_frontage'] = 87.000000        
train.loc[(train['lot_frontage'].isna()) & (train['lot_config'] == 'Inside'), 'lot_frontage'] = 66.759571

# %%
#Check if there are anymore missing values
train['lot_frontage'].isna().sum()
# Out:
# 0

# %% [markdown]
# ### 2.2.3 Clean up columns related to garage - 'garage_finish', 'garage_qual', 'garage_yr_blt, 'garage_cond', 'garage_type'

# %% [markdown]
# GarageFinish: Interior finish of the garage
#
# GarageYrBlt: Year garage was built
#
# GarageCond: Garage condition
#
# GarageCond: Garage condition
#
# GarageType: Garage location
#
# For all the columns above, if data is missing, we would assume that data should be NA (which essentially means no Garage).
# This is especially true when in all the columns, there are no data recorded as NA.
# This suggest that data might be left blank when there is no garage.

# %%
print(f'Number of missing values in garage_finish: {train.garage_finish.isna().sum()}')
print(f'% of missing values in garage_finish: {round(train.garage_finish.isna().sum()/rows*100,1)}%')
# Out:
# Number of missing values in garage_finish: 114
# % of missing values in garage_finish: 5.6%

# %%
#Check the value counts
train['garage_finish'].value_counts()
#No data recorded as NA. Hence, we would assome that Missing values might be no garbage (NA No Garage)
# Out:
# Unf    849
# RFn    579
# Fin    509
# Name: garage_finish, dtype: int64

# %%
#replace np.nan with NA
train.loc[(train['garage_finish'].isna()), 'garage_finish'] = 'NA'
#Check the value counts again
train['garage_finish'].value_counts()
#All 114 missing data replaced as NA
# Out:
# Unf    849
# RFn    579
# Fin    509
# NA     114
# Name: garage_finish, dtype: int64

# %%
print(f'Number of missing values in garage_qual: {train.garage_qual.isna().sum()}')
print(f'% of missing values in garage_qual: {round(train.garage_qual.isna().sum()/rows*100,1)}%')
# Out:
# Number of missing values in garage_qual: 114
# % of missing values in garage_qual: 5.6%

# %%
#Check the value counts
train['garage_qual'].value_counts()
#No data recorded as NA. Hence, we would assome that Missing values might be no garbage (NA No Garage)
# Out:
# TA    1832
# Fa      82
# Gd      18
# Ex       3
# Po       2
# Name: garage_qual, dtype: int64

# %%
#replace np.nan with NA
train.loc[(train['garage_qual'].isna()), 'garage_qual'] = 'NA'
#Check the value counts again
train['garage_qual'].value_counts()
#All 114 missing data replaced as NA
# Out:
# TA    1832
# NA     114
# Fa      82
# Gd      18
# Ex       3
# Po       2
# Name: garage_qual, dtype: int64

# %%
print(f'Number of missing values in garage_yr_blt: {train.garage_yr_blt.isna().sum()}')
print(f'% of missing values in garage_yr_blt: {round(train.garage_yr_blt.isna().sum()/rows*100,1)}%')
# Out:
# Number of missing values in garage_yr_blt: 114
# % of missing values in garage_yr_blt: 5.6%

# %%
#Have to remove NA first, before we can remove the decimal points
train.loc[(train['garage_yr_blt'].isna()), 'garage_yr_blt'] = 0.0

# %%
#Check if it is still null
train.loc[(train['garage_yr_blt'].isna())]
# Out:
# Empty DataFrame
# Columns: [ms_subclass, ms_zoning, lot_frontage, lot_area, street, lot_shape, land_contour, utilities, lot_config, land_slope, neighborhood, condition_1, condition_2, bldg_type, house_style, overall_qual, overall_cond, year_built, year_remod/add, roof_style, roof_matl, exterior_1st, exterior_2nd, mas_vnr_type, mas_vnr_area, exter_qual, exter_cond, foundation, bsmt_qual, bsmt_cond, bsmt_exposure, bsmtfin_type_1, bsmtfin_sf_1, bsmtfin_type_2, bsmtfin_sf_2, bsmt_unf_sf, total_bsmt_sf, heating, heating_qc, central_air, electrical, 1st_flr_sf, 2nd_flr_sf, low_qual_fin_sf, gr_liv_area, bsmt_full_bath, bsmt_half_bath, full_bath, half_bath, bedroom_abvgr, kitchen_abvgr, kitchen_qual, totrms_abvgrd, functional, fireplaces, garage_type, garage_yr_blt, garage_finish, garage_cars, garage_area, garage_qual, garage_cond, paved_drive, wood_deck_sf, open_porch_sf, enclosed_porch, 3ssn_porch, screen_porch, pool_area, misc_val, mo_sold, yr_sold, sale_type, saleprice]
# Index: []

# %%
#Remove decimal places for year
train['garage_yr_blt'] = train['garage_yr_blt'].astype(int)

# %%
#Check the value counts
train['garage_yr_blt'].value_counts()
#No data recorded as NA. Hence, we would assome that Missing values might be no garbage (NA No Garage)
# Out:
# 0       114
# 2005    105
# 2007     84
# 2006     80
# 2004     72
# 2003     66
# 1977     46
# 1998     45
# 2008     44
# 2000     41
# 2002     40
# 1999     39
# 1976     35
# 1993     34
# 1978     33
# 1968     32
# 1950     32
# 1958     32
# 1996     31
# 1956     31
# 1966     29
# 2001     27
# 1965     27
# 1967     26
# 1995     26
# 1997     26
# 1975     25
# 1964     25
# 1994     25
# 1962     25
# 1979     25
# 1954     25
# 1959     23
# 1992     22
# 1980     22
# 1963     22
# 1960     21
# 1920     21
# 1990     21
# 1940     20
# 1957     20
# 1930     20
# 1970     20
# 1973     20
# 1961     20
# 1953     19
# 1974     19
# 1969     18
# 1971     18
# 2009     17
# 1972     17
# 1939     16
# 1987     16
# 1955     15
# 1948     14
# 1988     14
# 1989     12
# 1985     12
# 1951     12
# 1981     11
# 1984     11
# 1991     10
# 1949     10
# 1945     10
# 1941     10
# 1986     10
# 1952     10
# 1926      8
# 1935      7
# 1936      7
# 1983      7
# 1938      6
# 1925      6
# 1982      6
# 1928      6
# 1922      6
# 1942      6
# 1910      5
# 1946      5
# 1916      5
# 1923      5
# 1927      4
# 1921      4
# 1924      4
# 1915      4
# 1937      4
# 1947      3
# 1900      3
# 1931      3
# 1932      2
# 1934      2
# 2010      2
# 1914      2
# 1929      2
# 2207      1
# 1917      1
# 1919      1
# 1918      1
# 1933      1
# 1896      1
# 1895      1
# Name: garage_yr_blt, dtype: int64

# %%
#Now, we can replace 0 with NA
train.loc[(train['garage_yr_blt'] == 0), 'garage_yr_blt'] = 'NA'
train['garage_yr_blt'].value_counts()
#All 114 missing data replaced as NA
# Out:
# NA      114
# 2005    105
# 2007     84
# 2006     80
# 2004     72
# 2003     66
# 1977     46
# 1998     45
# 2008     44
# 2000     41
# 2002     40
# 1999     39
# 1976     35
# 1993     34
# 1978     33
# 1950     32
# 1958     32
# 1968     32
# 1996     31
# 1956     31
# 1966     29
# 1965     27
# 2001     27
# 1995     26
# 1997     26
# 1967     26
# 1962     25
# 1964     25
# 1954     25
# 1975     25
# 1979     25
# 1994     25
# 1959     23
# 1963     22
# 1980     22
# 1992     22
# 1990     21
# 1960     21
# 1920     21
# 1973     20
# 1930     20
# 1940     20
# 1961     20
# 1957     20
# 1970     20
# 1953     19
# 1974     19
# 1969     18
# 1971     18
# 1972     17
# 2009     17
# 1987     16
# 1939     16
# 1955     15
# 1988     14
# 1948     14
# 1989     12
# 1951     12
# 1985     12
# 1981     11
# 1984     11
# 1991     10
# 1941     10
# 1945     10
# 1952     10
# 1986     10
# 1949     10
# 1926      8
# 1936      7
# 1935      7
# 1983      7
# 1928      6
# 1925      6
# 1922      6
# 1942      6
# 1938      6
# 1982      6
# 1946      5
# 1910      5
# 1916      5
# 1923      5
# 1921      4
# 1924      4
# 1927      4
# 1937      4
# 1915      4
# 1900      3
# 1931      3
# 1947      3
# 1914      2
# 1929      2
# 1932      2
# 1934      2
# 2010      2
# 1917      1
# 1918      1
# 1919      1
# 1933      1
# 2207      1
# 1896      1
# 1895      1
# Name: garage_yr_blt, dtype: int64

# %%
print(f'Number of missing values in garage_cond: {train.garage_cond.isna().sum()}')
print(f'% of missing values in garage_cond: {round(train.garage_cond.isna().sum()/rows*100,1)}%')
# Out:
# Number of missing values in garage_cond: 114
# % of missing values in garage_cond: 5.6%

# %%
train['garage_cond'].value_counts()
#GarageCond: Garage condition
# Out:
# TA    1868
# Fa      47
# Gd      12
# Po       8
# Ex       2
# Name: garage_cond, dtype: int64

# %%
#Replace null with 'NA'
train.loc[(train['garage_cond'].isna()), 'garage_cond'] = 'NA'
#Check if there is still null
train['garage_cond'].isna().sum()
# Out:
# 0

# %%
print(f'Number of missing values in garage_type: {train.garage_type.isna().sum()}')
print(f'% of missing values in garage_type: {round(train.garage_type.isna().sum()/rows*100,1)}%')
# Out:
# Number of missing values in garage_type: 113
# % of missing values in garage_type: 5.5%

# %%
#Check the value counts
train['garage_type'].value_counts()
#No data recorded as NA. Hence, we would assome that Missing values might be no garbage (NA No Garage)
# Out:
# Attchd     1213
# Detchd      536
# BuiltIn     132
# Basment      27
# 2Types       19
# CarPort      11
# Name: garage_type, dtype: int64

# %%
#replace np.nan with NA
train.loc[(train['garage_type'].isna()), 'garage_type'] = 'NA'
#Check value counts again
train['garage_type'].value_counts()
#Note that missing data only has 113 - and all changed to NA. 
#It suggests that there is one row of data with garage columns being NA, yet garage type is not NA.
# Out:
# Attchd     1213
# Detchd      536
# BuiltIn     132
# NA          113
# Basment      27
# 2Types       19
# CarPort      11
# Name: garage_type, dtype: int64

# %%
#Which is the row with garage type but everything else NA?
train[(train['garage_yr_blt'] == 'NA') & (train['garage_type'] !='NA')]
# Out:
#      ms_subclass ms_zoning  lot_frontage  lot_area street lot_shape  \
# 1712          70        RM          50.0      9060   Pave       Reg
#
#      land_contour utilities lot_config land_slope neighborhood condition_1  \
# 1712          Lvl    AllPub     Inside        Gtl       IDOTRR        Norm
#
#      condition_2 bldg_type house_style  overall_qual  overall_cond  \
# 1712        Norm      1Fam      2Story             5             6
#
#       year_built  year_remod/add roof_style roof_matl exterior_1st  \
# 1712        1923            1999      Gable   CompShg      Wd Sdng
#
#      exterior_2nd mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation  \
# 1712      Plywood         None           0.0         TA         TA     BrkTil
#
#      bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1  \
# 1712        Gd        TA            No            ALQ         548.0
#
#      bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf heating  \
# 1712            Unf           0.0        311.0          859.0    GasA
#
#      heating_qc central_air electrical  1st_flr_sf  2nd_flr_sf  \
# 1712         Ex           Y      SBrkr         942         886
#
#       low_qual_fin_sf  gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  \
# 1712                0         1828             0.0             0.0          2
#
#       half_bath  bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd  \
# 1712          0              3              1           Gd              6
#
#      functional  fireplaces garage_type garage_yr_blt garage_finish  \
# 1712        Typ           0      Detchd            NA            NA
#
#       garage_cars  garage_area garage_qual garage_cond paved_drive  \
# 1712          NaN          NaN          NA          NA           Y
#
#       wood_deck_sf  open_porch_sf  enclosed_porch  3ssn_porch  screen_porch  \
# 1712           174              0             212           0             0
#
#       pool_area  misc_val  mo_sold  yr_sold sale_type  saleprice
# 1712          0         0        3     2007       WD      150909

# %%
#Might be a data error. Hence, should change garage_type to NA
train.loc[(train['garage_yr_blt'] == 'NA') & (train['garage_type'] !='NA'), 'garage_type'] = 'NA'
#Check if data has been replaced
train[(train['garage_yr_blt'] == 'NA') & (train['garage_type'] !='NA')]
# Out:
# Empty DataFrame
# Columns: [ms_subclass, ms_zoning, lot_frontage, lot_area, street, lot_shape, land_contour, utilities, lot_config, land_slope, neighborhood, condition_1, condition_2, bldg_type, house_style, overall_qual, overall_cond, year_built, year_remod/add, roof_style, roof_matl, exterior_1st, exterior_2nd, mas_vnr_type, mas_vnr_area, exter_qual, exter_cond, foundation, bsmt_qual, bsmt_cond, bsmt_exposure, bsmtfin_type_1, bsmtfin_sf_1, bsmtfin_type_2, bsmtfin_sf_2, bsmt_unf_sf, total_bsmt_sf, heating, heating_qc, central_air, electrical, 1st_flr_sf, 2nd_flr_sf, low_qual_fin_sf, gr_liv_area, bsmt_full_bath, bsmt_half_bath, full_bath, half_bath, bedroom_abvgr, kitchen_abvgr, kitchen_qual, totrms_abvgrd, functional, fireplaces, garage_type, garage_yr_blt, garage_finish, garage_cars, garage_area, garage_qual, garage_cond, paved_drive, wood_deck_sf, open_porch_sf, enclosed_porch, 3ssn_porch, screen_porch, pool_area, misc_val, mo_sold, yr_sold, sale_type, saleprice]
# Index: []

# %% [markdown]
# ### 2.2.4 Clean up columns related to basement - 'bsmt_exposure', 'bsmtfin_type_2', 'bsmtfin_type_1, 'bsmt_cond', 'bsmt_qual'

# %% [markdown]
# Bsmt Exposure: Refers to walkout or garden level walls
#
# BsmtFinType2: Quality of second finished area (if present)
#
# BsmtFinType1: Quality of basement finished area
#
# BsmtCond: General condition of the basement
#
# BsmtQual: Height of the basement
#
# For all the columns above, if data is missing, we would assume that data should be NA (which essentially means no basement).
# This is especially true when in all the columns, there are no data recorded as NA.
# This suggest that data might be left blank when there is no basement.

# %%
print(f'Number of missing values in bsmt_exposure: {train.bsmt_exposure.isna().sum()}')
print(f'% of missing values in bsmt_exposure: {round(train.bsmt_exposure.isna().sum()/rows*100,1)}%')
# Out:
# Number of missing values in bsmt_exposure: 58
# % of missing values in bsmt_exposure: 2.8%

# %%
#Check the value counts
train['bsmt_exposure'].value_counts()
#No data recorded as NA. Hence, we would assome that Missing values might be no basement (NA No Basement)
# Out:
# No    1339
# Av     288
# Gd     203
# Mn     163
# Name: bsmt_exposure, dtype: int64

# %%
#replace np.nan with NA
train.loc[(train['bsmt_exposure'].isna()), 'bsmt_exposure'] = 'NA'
#Check the value counts again
train['bsmt_exposure'].value_counts()
#58 missing values replaced as NA
# Out:
# No    1339
# Av     288
# Gd     203
# Mn     163
# NA      58
# Name: bsmt_exposure, dtype: int64

# %%
print(f'Number of missing values in bsmtfin_type_2: {train.bsmtfin_type_2.isna().sum()}')
print(f'% of missing values in bsmtfin_type_2: {round(train.bsmtfin_type_2.isna().sum()/rows*100,1)}%')
# Out:
# Number of missing values in bsmtfin_type_2: 56
# % of missing values in bsmtfin_type_2: 2.7%

# %%
#Check the value counts
train['bsmtfin_type_2'].value_counts()
#No data recorded as NA. Hence, we would assome that Missing values might be no basement (NA No Basement)
# Out:
# Unf    1749
# Rec      80
# LwQ      60
# BLQ      48
# ALQ      35
# GLQ      23
# Name: bsmtfin_type_2, dtype: int64

# %%
#replace np.nan with NA
train.loc[(train['bsmtfin_type_2'].isna()), 'bsmtfin_type_2'] = 'NA'
#Check the value counts again
train['bsmtfin_type_2'].value_counts()
#56 missing values replaced as NA
#Note that missing data only has 56 - and all changed to NA. 
#It suggests that there are 2 rows of data with bsmt_exposure being NA, yet bsmtfin_type_2 is not NA.
# Out:
# Unf    1749
# Rec      80
# LwQ      60
# NA       56
# BLQ      48
# ALQ      35
# GLQ      23
# Name: bsmtfin_type_2, dtype: int64

# %%
#Which are the rows with bsmt_exposure = NA but bsmtfin_type_2 is not NA?
train[(train['bsmtfin_type_2'] != 'NA') & (train['bsmt_exposure'] =='NA')]
# Out:
#      ms_subclass ms_zoning  lot_frontage  lot_area street lot_shape  \
# 1456          60        FV          81.0     10411   Pave       Reg
# 1547          20        RL          73.0      8987   Pave       Reg
# 1997          60        RL          65.0     14006   Pave       IR1
#
#      land_contour utilities lot_config land_slope neighborhood condition_1  \
# 1456          Lvl    AllPub     Corner        Gtl      Somerst        Norm
# 1547          Lvl    AllPub     Inside        Gtl      Somerst        Norm
# 1997          Lvl    AllPub     Inside        Gtl      CollgCr        Norm
#
#      condition_2 bldg_type house_style  overall_qual  overall_cond  \
# 1456        Norm      1Fam      2Story             5             5
# 1547        Norm      1Fam      1Story             8             5
# 1997        Norm      1Fam      2Story             7             5
#
#       year_built  year_remod/add roof_style roof_matl exterior_1st  \
# 1456        2007            2007      Gable   CompShg      VinylSd
# 1547        2005            2006      Gable   CompShg      VinylSd
# 1997        2002            2002      Gable   CompShg      VinylSd
#
#      exterior_2nd mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation  \
# 1456      VinylSd         None           0.0         Gd         TA     CBlock
# 1547      VinylSd      BrkFace         226.0         Gd         TA      PConc
# 1997      VinylSd      BrkFace         144.0         Gd         TA      PConc
#
#      bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1  \
# 1456        Gd        TA            NA            Unf           0.0
# 1547        Gd        TA            NA            Unf           0.0
# 1997        Gd        TA            NA            Unf           0.0
#
#      bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf heating  \
# 1456            Unf           0.0        725.0          725.0    GasA
# 1547            Unf           0.0       1595.0         1595.0    GasA
# 1997            Unf           0.0        936.0          936.0    GasA
#
#      heating_qc central_air electrical  1st_flr_sf  2nd_flr_sf  \
# 1456         Ex           Y      SBrkr         725         863
# 1547         Ex           Y      SBrkr        1595           0
# 1997         Ex           Y      SBrkr         936         840
#
#       low_qual_fin_sf  gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  \
# 1456                0         1588             0.0             0.0          3
# 1547                0         1595             0.0             0.0          2
# 1997                0         1776             0.0             0.0          2
#
#       half_bath  bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd  \
# 1456          0              3              1           Gd              8
# 1547          0              2              1           Gd              6
# 1997          1              3              1           Gd              7
#
#      functional  fireplaces garage_type garage_yr_blt garage_finish  \
# 1456        Typ           0      Attchd          2007           Unf
# 1547        Typ           1      Attchd          2005           RFn
# 1997        Typ           1      Attchd          2002           RFn
#
#       garage_cars  garage_area garage_qual garage_cond paved_drive  \
# 1456          2.0        561.0          TA          TA           Y
# 1547          3.0        880.0          TA          TA           Y
# 1997          2.0        474.0          TA          TA           Y
#
#       wood_deck_sf  open_porch_sf  enclosed_porch  3ssn_porch  screen_porch  \
# 1456             0              0               0           0             0
# 1547           144              0               0           0             0
# 1997           144             96               0           0             0
#
#       pool_area  misc_val  mo_sold  yr_sold sale_type  saleprice
# 1456          0         0        7     2007       New     212109
# 1547          0         0        5     2010       WD      221500
# 1997          0         0        2     2006       WD      192500

# %%
#Might be error, so change bsmt_exposure to NA
#Change this code to the one with OR
train.loc[(train['bsmtfin_type_2'] != 'NA') & (train['bsmt_exposure'] =='NA'), 'bsmtfin_type_2'] = 'NA'

# %%
#Check
train[(train['bsmtfin_type_2'] != 'NA') & (train['bsmt_exposure'] =='NA')]
# Out:
# Empty DataFrame
# Columns: [ms_subclass, ms_zoning, lot_frontage, lot_area, street, lot_shape, land_contour, utilities, lot_config, land_slope, neighborhood, condition_1, condition_2, bldg_type, house_style, overall_qual, overall_cond, year_built, year_remod/add, roof_style, roof_matl, exterior_1st, exterior_2nd, mas_vnr_type, mas_vnr_area, exter_qual, exter_cond, foundation, bsmt_qual, bsmt_cond, bsmt_exposure, bsmtfin_type_1, bsmtfin_sf_1, bsmtfin_type_2, bsmtfin_sf_2, bsmt_unf_sf, total_bsmt_sf, heating, heating_qc, central_air, electrical, 1st_flr_sf, 2nd_flr_sf, low_qual_fin_sf, gr_liv_area, bsmt_full_bath, bsmt_half_bath, full_bath, half_bath, bedroom_abvgr, kitchen_abvgr, kitchen_qual, totrms_abvgrd, functional, fireplaces, garage_type, garage_yr_blt, garage_finish, garage_cars, garage_area, garage_qual, garage_cond, paved_drive, wood_deck_sf, open_porch_sf, enclosed_porch, 3ssn_porch, screen_porch, pool_area, misc_val, mo_sold, yr_sold, sale_type, saleprice]
# Index: []

# %%
print(f'Number of missing values in bsmtfin_type_1: {train.bsmtfin_type_1.isna().sum()}')
print(f'% of missing values in bsmtfin_type_1: {round(train.bsmtfin_type_1.isna().sum()/rows*100,1)}%')
# Out:
# Number of missing values in bsmtfin_type_1: 55
# % of missing values in bsmtfin_type_1: 2.7%

# %%
train['bsmtfin_type_1'].value_counts()
#No data recorded as NA. Hence, we would assome that Missing values might be no basement (NA No Basement)
# Out:
# GLQ    615
# Unf    603
# ALQ    293
# BLQ    200
# Rec    183
# LwQ    102
# Name: bsmtfin_type_1, dtype: int64

# %%
train.loc[(train['bsmtfin_type_1'].isna()), 'bsmtfin_type_1'] = 'NA'
train['bsmtfin_type_1'].value_counts()
# Out:
# GLQ    615
# Unf    603
# ALQ    293
# BLQ    200
# Rec    183
# LwQ    102
# NA      55
# Name: bsmtfin_type_1, dtype: int64

# %%
#55 missing values replaced as NA
#Note that missing data only has 55 - and all changed to NA. 
#It suggests that there are 3 rows of data with bsmt_exposure being NA, yet bsmtfin_type_2 is not NA.

# %%
#Which are the rows with bsmt_exposure = NA but bsmtfin_type_2 is not NA?
train[(train['bsmtfin_type_1'] != 'NA') & (train['bsmt_exposure'] =='NA')]
# Out:
#      ms_subclass ms_zoning  lot_frontage  lot_area street lot_shape  \
# 1456          60        FV          81.0     10411   Pave       Reg
# 1547          20        RL          73.0      8987   Pave       Reg
# 1997          60        RL          65.0     14006   Pave       IR1
#
#      land_contour utilities lot_config land_slope neighborhood condition_1  \
# 1456          Lvl    AllPub     Corner        Gtl      Somerst        Norm
# 1547          Lvl    AllPub     Inside        Gtl      Somerst        Norm
# 1997          Lvl    AllPub     Inside        Gtl      CollgCr        Norm
#
#      condition_2 bldg_type house_style  overall_qual  overall_cond  \
# 1456        Norm      1Fam      2Story             5             5
# 1547        Norm      1Fam      1Story             8             5
# 1997        Norm      1Fam      2Story             7             5
#
#       year_built  year_remod/add roof_style roof_matl exterior_1st  \
# 1456        2007            2007      Gable   CompShg      VinylSd
# 1547        2005            2006      Gable   CompShg      VinylSd
# 1997        2002            2002      Gable   CompShg      VinylSd
#
#      exterior_2nd mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation  \
# 1456      VinylSd         None           0.0         Gd         TA     CBlock
# 1547      VinylSd      BrkFace         226.0         Gd         TA      PConc
# 1997      VinylSd      BrkFace         144.0         Gd         TA      PConc
#
#      bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1  \
# 1456        Gd        TA            NA            Unf           0.0
# 1547        Gd        TA            NA            Unf           0.0
# 1997        Gd        TA            NA            Unf           0.0
#
#      bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf heating  \
# 1456             NA           0.0        725.0          725.0    GasA
# 1547             NA           0.0       1595.0         1595.0    GasA
# 1997             NA           0.0        936.0          936.0    GasA
#
#      heating_qc central_air electrical  1st_flr_sf  2nd_flr_sf  \
# 1456         Ex           Y      SBrkr         725         863
# 1547         Ex           Y      SBrkr        1595           0
# 1997         Ex           Y      SBrkr         936         840
#
#       low_qual_fin_sf  gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  \
# 1456                0         1588             0.0             0.0          3
# 1547                0         1595             0.0             0.0          2
# 1997                0         1776             0.0             0.0          2
#
#       half_bath  bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd  \
# 1456          0              3              1           Gd              8
# 1547          0              2              1           Gd              6
# 1997          1              3              1           Gd              7
#
#      functional  fireplaces garage_type garage_yr_blt garage_finish  \
# 1456        Typ           0      Attchd          2007           Unf
# 1547        Typ           1      Attchd          2005           RFn
# 1997        Typ           1      Attchd          2002           RFn
#
#       garage_cars  garage_area garage_qual garage_cond paved_drive  \
# 1456          2.0        561.0          TA          TA           Y
# 1547          3.0        880.0          TA          TA           Y
# 1997          2.0        474.0          TA          TA           Y
#
#       wood_deck_sf  open_porch_sf  enclosed_porch  3ssn_porch  screen_porch  \
# 1456             0              0               0           0             0
# 1547           144              0               0           0             0
# 1997           144             96               0           0             0
#
#       pool_area  misc_val  mo_sold  yr_sold sale_type  saleprice
# 1456          0         0        7     2007       New     212109
# 1547          0         0        5     2010       WD      221500
# 1997          0         0        2     2006       WD      192500

# %%
#Might be error, so change bsmt_exposure to NA
#Change this code to the one with OR
train.loc[(train['bsmtfin_type_1'] != 'NA') & (train['bsmt_exposure'] =='NA'), 'bsmtfin_type_1'] = 'NA'

# %%
#Check
train['bsmtfin_type_1'].value_counts()
# Out:
# GLQ    615
# Unf    600
# ALQ    293
# BLQ    200
# Rec    183
# LwQ    102
# NA      58
# Name: bsmtfin_type_1, dtype: int64

# %%
print(f'Number of missing values in bsmt_cond: {train.bsmt_cond.isna().sum()}')
print(f'% of missing values in bsmt_cond: {round(train.bsmt_cond.isna().sum()/rows*100,1)}%')
# Out:
# Number of missing values in bsmt_cond: 55
# % of missing values in bsmt_cond: 2.7%

# %%
train['bsmt_cond'].value_counts()
#BsmtCond: General condition of the basement
# Out:
# TA    1834
# Gd      89
# Fa      65
# Po       5
# Ex       3
# Name: bsmt_cond, dtype: int64

# %%
train.loc[(train['bsmt_cond'].isna()), 'bsmt_cond'] = 'NA'
train['bsmt_cond'].value_counts()
# Out:
# TA    1834
# Gd      89
# Fa      65
# NA      55
# Po       5
# Ex       3
# Name: bsmt_cond, dtype: int64

# %%
#55 missing values replaced as NA
#Note that missing data only has 55 - and all changed to NA. 
#It suggests that there are 3 rows of data with bsmt_exposure being NA, yet bsmtfin_type_2 is not NA.

# %%
#Which are the rows with bsmt_exposure = NA but bsmtfin_type_2 is not NA?
train[(train['bsmt_cond'] != 'NA') & (train['bsmt_exposure'] =='NA')]
# Out:
#      ms_subclass ms_zoning  lot_frontage  lot_area street lot_shape  \
# 1456          60        FV          81.0     10411   Pave       Reg
# 1547          20        RL          73.0      8987   Pave       Reg
# 1997          60        RL          65.0     14006   Pave       IR1
#
#      land_contour utilities lot_config land_slope neighborhood condition_1  \
# 1456          Lvl    AllPub     Corner        Gtl      Somerst        Norm
# 1547          Lvl    AllPub     Inside        Gtl      Somerst        Norm
# 1997          Lvl    AllPub     Inside        Gtl      CollgCr        Norm
#
#      condition_2 bldg_type house_style  overall_qual  overall_cond  \
# 1456        Norm      1Fam      2Story             5             5
# 1547        Norm      1Fam      1Story             8             5
# 1997        Norm      1Fam      2Story             7             5
#
#       year_built  year_remod/add roof_style roof_matl exterior_1st  \
# 1456        2007            2007      Gable   CompShg      VinylSd
# 1547        2005            2006      Gable   CompShg      VinylSd
# 1997        2002            2002      Gable   CompShg      VinylSd
#
#      exterior_2nd mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation  \
# 1456      VinylSd         None           0.0         Gd         TA     CBlock
# 1547      VinylSd      BrkFace         226.0         Gd         TA      PConc
# 1997      VinylSd      BrkFace         144.0         Gd         TA      PConc
#
#      bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1  \
# 1456        Gd        TA            NA             NA           0.0
# 1547        Gd        TA            NA             NA           0.0
# 1997        Gd        TA            NA             NA           0.0
#
#      bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf heating  \
# 1456             NA           0.0        725.0          725.0    GasA
# 1547             NA           0.0       1595.0         1595.0    GasA
# 1997             NA           0.0        936.0          936.0    GasA
#
#      heating_qc central_air electrical  1st_flr_sf  2nd_flr_sf  \
# 1456         Ex           Y      SBrkr         725         863
# 1547         Ex           Y      SBrkr        1595           0
# 1997         Ex           Y      SBrkr         936         840
#
#       low_qual_fin_sf  gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  \
# 1456                0         1588             0.0             0.0          3
# 1547                0         1595             0.0             0.0          2
# 1997                0         1776             0.0             0.0          2
#
#       half_bath  bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd  \
# 1456          0              3              1           Gd              8
# 1547          0              2              1           Gd              6
# 1997          1              3              1           Gd              7
#
#      functional  fireplaces garage_type garage_yr_blt garage_finish  \
# 1456        Typ           0      Attchd          2007           Unf
# 1547        Typ           1      Attchd          2005           RFn
# 1997        Typ           1      Attchd          2002           RFn
#
#       garage_cars  garage_area garage_qual garage_cond paved_drive  \
# 1456          2.0        561.0          TA          TA           Y
# 1547          3.0        880.0          TA          TA           Y
# 1997          2.0        474.0          TA          TA           Y
#
#       wood_deck_sf  open_porch_sf  enclosed_porch  3ssn_porch  screen_porch  \
# 1456             0              0               0           0             0
# 1547           144              0               0           0             0
# 1997           144             96               0           0             0
#
#       pool_area  misc_val  mo_sold  yr_sold sale_type  saleprice
# 1456          0         0        7     2007       New     212109
# 1547          0         0        5     2010       WD      221500
# 1997          0         0        2     2006       WD      192500

# %%
#Might be error, so change bsmt_exposure to NA
#Change this code to the one with OR
train.loc[(train['bsmt_cond'] != 'NA') & (train['bsmt_exposure'] =='NA'), 'bsmt_cond'] = 'NA'

# %%
#Check
train['bsmt_cond'].value_counts()
# Out:
# TA    1831
# Gd      89
# Fa      65
# NA      58
# Po       5
# Ex       3
# Name: bsmt_cond, dtype: int64

# %%
print(f'Number of missing values in bsmt_qual: {train.bsmt_qual.isna().sum()}')
print(f'% of missing values in bsmt_qual: {round(train.bsmt_qual.isna().sum()/rows*100,1)}%')
# Out:
# Number of missing values in bsmt_qual: 55
# % of missing values in bsmt_qual: 2.7%

# %%
train['bsmt_qual'].value_counts()
#BsmtQual: Height of the basement
# Out:
# TA    887
# Gd    864
# Ex    184
# Fa     60
# Po      1
# Name: bsmt_qual, dtype: int64

# %%
train.loc[(train['bsmt_qual'].isna()), 'bsmt_qual'] = 'NA'
train['bsmt_qual'].value_counts()
# Out:
# TA    887
# Gd    864
# Ex    184
# Fa     60
# NA     55
# Po      1
# Name: bsmt_qual, dtype: int64

# %%
#But this only has 55. Which is the row with bsmt_exposure but everything else NA?
train[(train['bsmt_qual'] != 'NA') & (train['bsmt_exposure'] =='NA')]
# Out:
#      ms_subclass ms_zoning  lot_frontage  lot_area street lot_shape  \
# 1456          60        FV          81.0     10411   Pave       Reg
# 1547          20        RL          73.0      8987   Pave       Reg
# 1997          60        RL          65.0     14006   Pave       IR1
#
#      land_contour utilities lot_config land_slope neighborhood condition_1  \
# 1456          Lvl    AllPub     Corner        Gtl      Somerst        Norm
# 1547          Lvl    AllPub     Inside        Gtl      Somerst        Norm
# 1997          Lvl    AllPub     Inside        Gtl      CollgCr        Norm
#
#      condition_2 bldg_type house_style  overall_qual  overall_cond  \
# 1456        Norm      1Fam      2Story             5             5
# 1547        Norm      1Fam      1Story             8             5
# 1997        Norm      1Fam      2Story             7             5
#
#       year_built  year_remod/add roof_style roof_matl exterior_1st  \
# 1456        2007            2007      Gable   CompShg      VinylSd
# 1547        2005            2006      Gable   CompShg      VinylSd
# 1997        2002            2002      Gable   CompShg      VinylSd
#
#      exterior_2nd mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation  \
# 1456      VinylSd         None           0.0         Gd         TA     CBlock
# 1547      VinylSd      BrkFace         226.0         Gd         TA      PConc
# 1997      VinylSd      BrkFace         144.0         Gd         TA      PConc
#
#      bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1  \
# 1456        Gd        NA            NA             NA           0.0
# 1547        Gd        NA            NA             NA           0.0
# 1997        Gd        NA            NA             NA           0.0
#
#      bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf heating  \
# 1456             NA           0.0        725.0          725.0    GasA
# 1547             NA           0.0       1595.0         1595.0    GasA
# 1997             NA           0.0        936.0          936.0    GasA
#
#      heating_qc central_air electrical  1st_flr_sf  2nd_flr_sf  \
# 1456         Ex           Y      SBrkr         725         863
# 1547         Ex           Y      SBrkr        1595           0
# 1997         Ex           Y      SBrkr         936         840
#
#       low_qual_fin_sf  gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  \
# 1456                0         1588             0.0             0.0          3
# 1547                0         1595             0.0             0.0          2
# 1997                0         1776             0.0             0.0          2
#
#       half_bath  bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd  \
# 1456          0              3              1           Gd              8
# 1547          0              2              1           Gd              6
# 1997          1              3              1           Gd              7
#
#      functional  fireplaces garage_type garage_yr_blt garage_finish  \
# 1456        Typ           0      Attchd          2007           Unf
# 1547        Typ           1      Attchd          2005           RFn
# 1997        Typ           1      Attchd          2002           RFn
#
#       garage_cars  garage_area garage_qual garage_cond paved_drive  \
# 1456          2.0        561.0          TA          TA           Y
# 1547          3.0        880.0          TA          TA           Y
# 1997          2.0        474.0          TA          TA           Y
#
#       wood_deck_sf  open_porch_sf  enclosed_porch  3ssn_porch  screen_porch  \
# 1456             0              0               0           0             0
# 1547           144              0               0           0             0
# 1997           144             96               0           0             0
#
#       pool_area  misc_val  mo_sold  yr_sold sale_type  saleprice
# 1456          0         0        7     2007       New     212109
# 1547          0         0        5     2010       WD      221500
# 1997          0         0        2     2006       WD      192500

# %%
#Might be error, so change bsmt_exposure to NA
#Change this code to the one with OR
train.loc[(train['bsmt_qual'] != 'NA') & (train['bsmt_exposure'] =='NA'), 'bsmt_qual'] = 'NA'

# %%
#Check
train[(train['bsmt_qual'] != 'NA') & (train['bsmt_exposure'] =='NA')]
# Out:
# Empty DataFrame
# Columns: [ms_subclass, ms_zoning, lot_frontage, lot_area, street, lot_shape, land_contour, utilities, lot_config, land_slope, neighborhood, condition_1, condition_2, bldg_type, house_style, overall_qual, overall_cond, year_built, year_remod/add, roof_style, roof_matl, exterior_1st, exterior_2nd, mas_vnr_type, mas_vnr_area, exter_qual, exter_cond, foundation, bsmt_qual, bsmt_cond, bsmt_exposure, bsmtfin_type_1, bsmtfin_sf_1, bsmtfin_type_2, bsmtfin_sf_2, bsmt_unf_sf, total_bsmt_sf, heating, heating_qc, central_air, electrical, 1st_flr_sf, 2nd_flr_sf, low_qual_fin_sf, gr_liv_area, bsmt_full_bath, bsmt_half_bath, full_bath, half_bath, bedroom_abvgr, kitchen_abvgr, kitchen_qual, totrms_abvgrd, functional, fireplaces, garage_type, garage_yr_blt, garage_finish, garage_cars, garage_area, garage_qual, garage_cond, paved_drive, wood_deck_sf, open_porch_sf, enclosed_porch, 3ssn_porch, screen_porch, pool_area, misc_val, mo_sold, yr_sold, sale_type, saleprice]
# Index: []

# %%
print(f'Number of missing values in mas_vnr_area: {train.mas_vnr_area.isna().sum()}')
print(f'% of missing values in mas_vnr_area: {round(train.mas_vnr_area.isna().sum()/rows*100,1)}%')
# Out:
# Number of missing values in mas_vnr_area: 22
# % of missing values in mas_vnr_area: 1.1%

# %%
train['mas_vnr_area'].value_counts()
#MasVnrArea: Masonry veneer area in square feet
# Out:
# 0.0       1216
# 120.0       11
# 176.0       10
# 200.0       10
# 210.0        9
# 180.0        9
# 72.0         9
# 16.0         9
# 108.0        9
# 132.0        8
# 40.0         8
# 144.0        7
# 186.0        7
# 170.0        7
# 128.0        6
# 340.0        6
# 256.0        6
# 60.0         6
# 178.0        6
# 140.0        6
# 84.0         6
# 203.0        6
# 272.0        5
# 106.0        5
# 216.0        5
# 260.0        5
# 145.0        5
# 76.0         5
# 504.0        5
# 288.0        5
# 148.0        5
# 302.0        5
# 168.0        5
# 360.0        5
# 112.0        5
# 300.0        5
# 174.0        5
# 44.0         5
# 164.0        5
# 160.0        5
# 320.0        5
# 143.0        5
# 252.0        5
# 196.0        4
# 126.0        4
# 242.0        4
# 513.0        4
# 30.0         4
# 50.0         4
# 240.0        4
# 130.0        4
# 192.0        4
# 336.0        4
# 456.0        4
# 68.0         4
# 246.0        4
# 80.0         4
# 183.0        4
# 136.0        4
# 172.0        4
# 232.0        4
# 270.0        4
# 165.0        3
# 100.0        3
# 480.0        3
# 90.0         3
# 110.0        3
# 425.0        3
# 157.0        3
# 184.0        3
# 220.0        3
# 125.0        3
# 42.0         3
# 135.0        3
# 82.0         3
# 306.0        3
# 250.0        3
# 41.0         3
# 466.0        3
# 54.0         3
# 85.0         3
# 198.0        3
# 298.0        3
# 554.0        3
# 158.0        3
# 1.0          3
# 162.0        3
# 122.0        3
# 206.0        3
# 86.0         3
# 289.0        3
# 268.0        3
# 212.0        3
# 238.0        3
# 32.0         3
# 442.0        3
# 96.0         3
# 150.0        3
# 98.0         3
# 74.0         3
# 275.0        3
# 23.0         3
# 290.0        3
# 94.0         3
# 248.0        3
# 115.0        2
# 450.0        2
# 88.0         2
# 344.0        2
# 284.0        2
# 280.0        2
# 226.0        2
# 295.0        2
# 52.0         2
# 92.0         2
# 18.0         2
# 424.0        2
# 472.0        2
# 245.0        2
# 22.0         2
# 113.0        2
# 119.0        2
# 660.0        2
# 28.0         2
# 243.0        2
# 218.0        2
# 365.0        2
# 310.0        2
# 20.0         2
# 102.0        2
# 105.0        2
# 95.0         2
# 510.0        2
# 338.0        2
# 292.0        2
# 99.0         2
# 294.0        2
# 208.0        2
# 244.0        2
# 402.0        2
# 204.0        2
# 506.0        2
# 420.0        2
# 51.0         2
# 351.0        2
# 146.0        2
# 24.0         2
# 190.0        2
# 304.0        2
# 194.0        2
# 312.0        2
# 296.0        2
# 264.0        2
# 166.0        2
# 38.0         2
# 36.0         2
# 14.0         2
# 254.0        2
# 138.0        2
# 650.0        2
# 234.0        2
# 163.0        2
# 228.0        2
# 56.0         2
# 236.0        2
# 189.0        2
# 188.0        2
# 335.0        2
# 182.0        2
# 309.0        2
# 202.0        2
# 104.0        2
# 101.0        2
# 383.0        2
# 600.0        2
# 116.0        2
# 70.0         2
# 473.0        2
# 278.0        2
# 257.0        1
# 434.0        1
# 332.0        1
# 239.0        1
# 567.0        1
# 562.0        1
# 519.0        1
# 470.0        1
# 525.0        1
# 75.0         1
# 31.0         1
# 348.0        1
# 227.0        1
# 205.0        1
# 387.0        1
# 616.0        1
# 235.0        1
# 259.0        1
# 397.0        1
# 1031.0       1
# 353.0        1
# 366.0        1
# 945.0        1
# 261.0        1
# 1095.0       1
# 1047.0       1
# 362.0        1
# 124.0        1
# 522.0        1
# 199.0        1
# 426.0        1
# 233.0        1
# 3.0          1
# 291.0        1
# 1115.0       1
# 359.0        1
# 46.0         1
# 58.0         1
# 87.0         1
# 65.0         1
# 222.0        1
# 432.0        1
# 418.0        1
# 514.0        1
# 724.0        1
# 385.0        1
# 491.0        1
# 632.0        1
# 380.0        1
# 378.0        1
# 652.0        1
# 738.0        1
# 1600.0       1
# 375.0        1
# 970.0        1
# 860.0        1
# 322.0        1
# 224.0        1
# 526.0        1
# 323.0        1
# 436.0        1
# 114.0        1
# 364.0        1
# 492.0        1
# 169.0        1
# 886.0        1
# 167.0        1
# 127.0        1
# 748.0        1
# 45.0         1
# 674.0        1
# 1050.0       1
# 274.0        1
# 342.0        1
# 530.0        1
# 39.0         1
# 902.0        1
# 177.0        1
# 276.0        1
# 668.0        1
# 528.0        1
# 894.0        1
# 730.0        1
# 400.0        1
# 356.0        1
# 149.0        1
# 500.0        1
# 673.0        1
# 1129.0       1
# 604.0        1
# 568.0        1
# 117.0        1
# 328.0        1
# 412.0        1
# 579.0        1
# 391.0        1
# 283.0        1
# 258.0        1
# 816.0        1
# 57.0         1
# 153.0        1
# 381.0        1
# 171.0        1
# 355.0        1
# 479.0        1
# 225.0        1
# 305.0        1
# 214.0        1
# 221.0        1
# 760.0        1
# 1224.0       1
# 518.0        1
# 376.0        1
# 452.0        1
# 333.0        1
# 215.0        1
# 281.0        1
# 66.0         1
# 350.0        1
# 69.0         1
# 368.0        1
# 451.0        1
# 468.0        1
# 571.0        1
# 502.0        1
# 47.0         1
# 315.0        1
# 230.0        1
# 664.0        1
# 62.0         1
# 337.0        1
# 630.0        1
# 318.0        1
# 766.0        1
# 662.0        1
# 705.0        1
# 134.0        1
# 572.0        1
# 64.0         1
# 922.0        1
# 443.0        1
# 422.0        1
# 109.0        1
# 430.0        1
# 279.0        1
# 710.0        1
# 772.0        1
# 410.0        1
# 299.0        1
# 97.0         1
# 123.0        1
# 251.0        1
# 406.0        1
# 161.0        1
# 731.0        1
# 394.0        1
# 219.0        1
# 118.0        1
# 327.0        1
# 692.0        1
# 255.0        1
# 423.0        1
# 382.0        1
# 564.0        1
# 651.0        1
# 262.0        1
# 237.0        1
# 121.0        1
# 1110.0       1
# 156.0        1
# 379.0        1
# 714.0        1
# 142.0        1
# 647.0        1
# 734.0        1
# 63.0         1
# 67.0         1
# 89.0         1
# 27.0         1
# 361.0        1
# 603.0        1
# 197.0        1
# 154.0        1
# 370.0        1
# 253.0        1
# 324.0        1
# 640.0        1
# 179.0        1
# 541.0        1
# 576.0        1
# 796.0        1
# 573.0        1
# 372.0        1
# 428.0        1
# Name: mas_vnr_area, dtype: int64

# %%
print(f'Number of missing values in mas_vnr_type: {train.mas_vnr_type.isna().sum()}')
print(f'% of missing values in mas_vnr_type: {round(train.mas_vnr_type.isna().sum()/rows*100,1)}%')
# Out:
# Number of missing values in mas_vnr_type: 22
# % of missing values in mas_vnr_type: 1.1%

# %%
train['mas_vnr_type'].value_counts()
#MasVnrType: Masonry veneer type
# Out:
# None       1218
# BrkFace     630
# Stone       168
# BrkCmn       13
# Name: mas_vnr_type, dtype: int64

# %%
#Check for rows that are both null
train[(train['mas_vnr_area'].isna()) & (train['mas_vnr_type'].isna())]
# Out:
#      ms_subclass ms_zoning  lot_frontage  lot_area street lot_shape  \
# 22            60        RL    103.000000     12867   Pave       IR1
# 41            20        RL    107.000000     13891   Pave       Reg
# 86            20        RL     67.000000     10083   Pave       Reg
# 212           20        FV     90.000000      7993   Pave       IR1
# 276           20        RL     75.000000      8050   Pave       Reg
# 338           60        FV    112.000000     12217   Pave       IR1
# 431           60        RL     75.000000      9473   Pave       Reg
# 451           20        RL     87.000000     10037   Pave       Reg
# 591          120        FV     35.000000      4274   Pave       IR1
# 844          120        FV     30.000000      5330   Pave       IR2
# 913           20        RL     54.734375     32668   Pave       IR1
# 939           20        FV     95.000000     11639   Pave       Reg
# 1025          20        RL     85.000000      9965   Pave       Reg
# 1244          60        RL     83.250000     12891   Pave       IR1
# 1306          80        RL     83.250000     11950   Pave       IR1
# 1430          60        FV     66.759571      7500   Pave       Reg
# 1434          60        FV     65.000000      8125   Pave       Reg
# 1606          60        RL     66.759571      7750   Pave       Reg
# 1699          20        RL     68.000000      8298   Pave       IR1
# 1815          20        RL     49.000000     15218   Pave       IR1
# 1820          60        RL     59.000000     15810   Pave       IR1
# 1941          60        RL     66.759571      7851   Pave       Reg
#
#      land_contour utilities lot_config land_slope neighborhood condition_1  \
# 22            Lvl    AllPub     Corner        Gtl      NridgHt        Norm
# 41            Lvl    AllPub     Inside        Gtl      NridgHt        Norm
# 86            Lvl    AllPub     Inside        Gtl      SawyerW        Norm
# 212           Lvl    AllPub     Inside        Gtl      Somerst        Norm
# 276           Lvl    AllPub     Inside        Gtl      Edwards        Norm
# 338           Lvl    AllPub     Inside        Gtl      Somerst        Norm
# 431           Lvl    AllPub     Inside        Gtl      CollgCr        Norm
# 451           Lvl    AllPub     Corner        Gtl      Somerst       Feedr
# 591           Lvl    AllPub     Inside        Gtl      Somerst        Norm
# 844           Lvl    AllPub     Inside        Gtl      Somerst        Norm
# 913           Lvl    AllPub    CulDSac        Gtl      Crawfor        Norm
# 939           Lvl    AllPub     Corner        Gtl      Somerst        Norm
# 1025          Lvl    AllPub        FR2        Gtl      Somerst       Feedr
# 1244          Lvl    AllPub     Corner        Gtl      Gilbert        Norm
# 1306          Lvl    AllPub     Corner        Gtl      Gilbert        Norm
# 1430          Lvl    AllPub     Inside        Gtl      Somerst        Norm
# 1434          Lvl    AllPub     Inside        Gtl      Somerst        Norm
# 1606          Lvl    AllPub     Inside        Gtl      Gilbert        RRAn
# 1699          HLS    AllPub     Inside        Gtl       Timber        Norm
# 1815          Lvl    AllPub    CulDSac        Gtl      Somerst        RRAn
# 1820          Lvl    AllPub     Inside        Gtl      Gilbert        RRAn
# 1941          Lvl    AllPub     Inside        Gtl      Gilbert        Norm
#
#      condition_2 bldg_type house_style  overall_qual  overall_cond  \
# 22          Norm      1Fam      2Story             8             5
# 41          Norm      1Fam      1Story            10             5
# 86          Norm      1Fam      1Story             7             5
# 212         Norm      1Fam      1Story             7             5
# 276         Norm      1Fam      1Story             6             5
# 338         Norm      1Fam      2Story             8             5
# 431         Norm      1Fam      2Story             8             5
# 451         Norm      1Fam      1Story             8             5
# 591         Norm    TwnhsE      1Story             7             5
# 844         Norm    TwnhsE      1Story             8             5
# 913         Norm      1Fam      1Story             6             3
# 939         Norm      1Fam      1Story             7             5
# 1025        Norm      1Fam      1Story             7             5
# 1244        Norm      1Fam      2Story             8             5
# 1306        Norm      1Fam        SLvl             7             5
# 1430        Norm      1Fam      2Story             7             5
# 1434        Norm      1Fam      2Story             7             6
# 1606        Norm      1Fam      2Story             7             5
# 1699        Norm      1Fam      1Story             8             5
# 1815        Norm      1Fam      1Story             8             5
# 1820        Norm      1Fam      2Story             6             5
# 1941        Norm      1Fam      2Story             6             5
#
#       year_built  year_remod/add roof_style roof_matl exterior_1st  \
# 22          2005            2006      Gable   CompShg      CemntBd
# 41          2006            2006      Gable   CompShg      VinylSd
# 86          2003            2003      Gable   CompShg      VinylSd
# 212         2008            2009      Gable   CompShg      VinylSd
# 276         2002            2002      Gable   CompShg      VinylSd
# 338         2007            2007        Hip   CompShg      WdShing
# 431         2002            2002      Gable   CompShg      VinylSd
# 451         2006            2007        Hip   CompShg      VinylSd
# 591         2006            2007      Gable   CompShg      VinylSd
# 844         2006            2007      Gable   CompShg      VinylSd
# 913         1957            1975        Hip   CompShg      Wd Sdng
# 939         2007            2008      Gable   CompShg      CemntBd
# 1025        2007            2007      Gable   CompShg      VinylSd
# 1244        2002            2002      Gable   CompShg      VinylSd
# 1306        2003            2003      Gable   CompShg      VinylSd
# 1430        2002            2002      Gable   CompShg      VinylSd
# 1434        2007            2007      Gable   CompShg      CemntBd
# 1606        2002            2002      Gable   CompShg      VinylSd
# 1699        2006            2007        Hip   CompShg      VinylSd
# 1815        2006            2006      Gable   CompShg      VinylSd
# 1820        2007            2007      Gable   CompShg      VinylSd
# 1941        2002            2002      Gable   CompShg      VinylSd
#
#      exterior_2nd mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation  \
# 22        CmentBd          NaN           NaN         Gd         TA      PConc
# 41        VinylSd          NaN           NaN         Ex         TA      PConc
# 86        VinylSd          NaN           NaN         Gd         TA      PConc
# 212       VinylSd          NaN           NaN         Gd         TA      PConc
# 276       VinylSd          NaN           NaN         TA         TA      PConc
# 338       Wd Shng          NaN           NaN         Gd         TA      PConc
# 431       VinylSd          NaN           NaN         Gd         TA      PConc
# 451       VinylSd          NaN           NaN         Gd         TA      PConc
# 591       VinylSd          NaN           NaN         Gd         TA      PConc
# 844       VinylSd          NaN           NaN         Gd         TA      PConc
# 913         Stone          NaN           NaN         Gd         TA      PConc
# 939       CmentBd          NaN           NaN         Gd         TA      PConc
# 1025      VinylSd          NaN           NaN         Gd         TA      PConc
# 1244      VinylSd          NaN           NaN         Gd         TA      PConc
# 1306      VinylSd          NaN           NaN         Gd         TA      PConc
# 1430      VinylSd          NaN           NaN         Gd         TA      PConc
# 1434      CmentBd          NaN           NaN         Gd         TA      PConc
# 1606      VinylSd          NaN           NaN         Gd         TA      PConc
# 1699      VinylSd          NaN           NaN         Gd         TA      PConc
# 1815      VinylSd          NaN           NaN         Gd         TA      PConc
# 1820      VinylSd          NaN           NaN         Gd         TA     CBlock
# 1941      VinylSd          NaN           NaN         Gd         TA      PConc
#
#      bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1  \
# 22          Ex        TA            Av            Unf           0.0
# 41          Ex        Gd            Gd            GLQ        1386.0
# 86          Gd        TA            No            GLQ         833.0
# 212         Ex        TA            No            Unf           0.0
# 276         Gd        TA            Av            GLQ         475.0
# 338         Ex        TA            Av            GLQ         745.0
# 431         Gd        TA            No            GLQ         804.0
# 451         Ex        TA            No            GLQ         666.0
# 591         Gd        TA            No            GLQ        1106.0
# 844         Gd        TA            No            Unf           0.0
# 913         TA        TA            No            Rec        1219.0
# 939         Gd        TA            No            Unf           0.0
# 1025        Gd        TA            No            Unf           0.0
# 1244        Ex        TA            No            GLQ         651.0
# 1306        Gd        TA            No            Unf           0.0
# 1430        Gd        TA            No            Unf           0.0
# 1434        Gd        TA            No            Unf           0.0
# 1606        Gd        TA            No            Unf           0.0
# 1699        Gd        TA            Av            GLQ         583.0
# 1815        Ex        Gd            No            GLQ        1562.0
# 1820        Gd        TA            No            Unf           0.0
# 1941        Gd        TA            No            GLQ         625.0
#
#      bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf heating  \
# 22              Unf           0.0       1209.0         1209.0    GasA
# 41              Unf           0.0        690.0         2076.0    GasA
# 86              Unf           0.0        343.0         1176.0    GasA
# 212             Unf           0.0       1436.0         1436.0    GasA
# 276             ALQ         297.0        142.0          914.0    GasA
# 338             Unf           0.0        210.0          955.0    GasA
# 431             Unf           0.0        324.0         1128.0    GasA
# 451             Unf           0.0        794.0         1460.0    GasA
# 591             Unf           0.0        135.0         1241.0    GasA
# 844             Unf           0.0       1550.0         1550.0    GasA
# 913             Unf           0.0        816.0         2035.0    GasA
# 939             Unf           0.0       1428.0         1428.0    GasA
# 1025            Unf           0.0       1528.0         1528.0    GasA
# 1244            Unf           0.0        219.0          870.0    GasA
# 1306            Unf           0.0        384.0          384.0    GasA
# 1430            Unf           0.0        952.0          952.0    GasA
# 1434            Unf           0.0        813.0          813.0    GasA
# 1606            Unf           0.0        707.0          707.0    GasA
# 1699            Unf           0.0        963.0         1546.0    GasA
# 1815            Unf           0.0        108.0         1670.0    GasA
# 1820            Unf           0.0        768.0          768.0    GasA
# 1941            Unf           0.0        235.0          860.0    GasA
#
#      heating_qc central_air electrical  1st_flr_sf  2nd_flr_sf  \
# 22           Ex           Y      SBrkr        1209        1044
# 41           Ex           Y      SBrkr        2076           0
# 86           Ex           Y      SBrkr        1200           0
# 212          Ex           Y      SBrkr        1436           0
# 276          Ex           Y      SBrkr         914           0
# 338          Ex           Y      SBrkr         955         925
# 431          Ex           Y      SBrkr        1128         903
# 451          Ex           Y      SBrkr        1460           0
# 591          Ex           Y      SBrkr        1241           0
# 844          Ex           Y      SBrkr        1550           0
# 913          TA           Y      SBrkr        2515           0
# 939          Ex           Y      SBrkr        1428           0
# 1025         Ex           Y      SBrkr        1528           0
# 1244         Ex           Y      SBrkr         878        1126
# 1306         Ex           Y      SBrkr         754         640
# 1430         Ex           Y      SBrkr         952         860
# 1434         Ex           Y      SBrkr         822         843
# 1606         Ex           Y      SBrkr         707         707
# 1699         Ex           Y      SBrkr        1564           0
# 1815         Ex           Y      SBrkr        1670           0
# 1820         Ex           Y      SBrkr         768         728
# 1941         Ex           Y      SBrkr         860        1100
#
#       low_qual_fin_sf  gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  \
# 22                  0         2253             0.0             0.0          2
# 41                  0         2076             1.0             0.0          2
# 86                  0         1200             1.0             0.0          2
# 212                 0         1436             0.0             0.0          2
# 276                 0          914             1.0             0.0          1
# 338                 0         1880             1.0             0.0          2
# 431                 0         2031             1.0             0.0          2
# 451                 0         1460             0.0             0.0          2
# 591                 0         1241             1.0             0.0          1
# 844                 0         1550             0.0             0.0          2
# 913                 0         2515             1.0             0.0          3
# 939                 0         1428             0.0             0.0          2
# 1025                0         1528             0.0             0.0          3
# 1244                0         2004             1.0             0.0          2
# 1306                0         1394             0.0             0.0          2
# 1430                0         1812             0.0             0.0          2
# 1434                0         1665             0.0             0.0          2
# 1606                0         1414             0.0             0.0          2
# 1699                0         1564             0.0             0.0          2
# 1815                0         1670             1.0             0.0          2
# 1820                0         1496             0.0             0.0          3
# 1941                0         1960             1.0             0.0          2
#
#       half_bath  bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd  \
# 22            1              3              1           Ex              8
# 41            1              2              1           Ex              7
# 86            0              2              1           Gd              5
# 212           0              3              1           Gd              6
# 276           0              2              1           Gd              4
# 338           1              3              1           Ex              8
# 431           1              3              1           Gd              7
# 451           0              3              1           Gd              6
# 591           1              1              1           Gd              4
# 844           1              2              1           Gd              5
# 913           0              4              2           TA              9
# 939           0              3              1           Gd              6
# 1025          2              3              1           Gd              6
# 1244          1              4              1           Gd              8
# 1306          1              3              1           Gd              7
# 1430          1              3              1           TA              7
# 1434          1              3              1           Gd              7
# 1606          1              3              1           Gd              6
# 1699          0              2              1           Ex              6
# 1815          1              2              1           Gd              6
# 1820          0              3              1           Gd              7
# 1941          1              4              1           Gd              8
#
#      functional  fireplaces garage_type garage_yr_blt garage_finish  \
# 22          Typ           1      Attchd          2005           Fin
# 41          Typ           1      Attchd          2006           Fin
# 86          Typ           0      Attchd          2003           RFn
# 212         Typ           0      Attchd          2008           Fin
# 276         Typ           0          NA            NA            NA
# 338         Typ           1      Attchd          2007           Fin
# 431         Typ           1      Attchd          2002           RFn
# 451         Typ           1      Attchd          2006           Fin
# 591         Typ           0      Attchd          2007           Fin
# 844         Typ           0      Attchd          2007           Fin
# 913        Maj1           2      Attchd          1975           RFn
# 939         Typ           0      Attchd          2007           Fin
# 1025        Typ           1      Attchd          2007           Unf
# 1244        Typ           1     BuiltIn          2002           Fin
# 1306        Typ           1     BuiltIn          2003           Fin
# 1430        Typ           1      Attchd          2002           RFn
# 1434        Typ           0      Attchd          2007           RFn
# 1606        Typ           1      Attchd          2002           Fin
# 1699        Typ           1      Attchd          2207           RFn
# 1815        Typ           1      Attchd          2006           RFn
# 1820        Typ           0      Attchd          2007           Unf
# 1941        Typ           2     BuiltIn          2002           Fin
#
#       garage_cars  garage_area garage_qual garage_cond paved_drive  \
# 22            2.0        575.0          TA          TA           Y
# 41            3.0        850.0          TA          TA           Y
# 86            2.0        555.0          TA          TA           Y
# 212           2.0        529.0          TA          TA           Y
# 276           0.0          0.0          NA          NA           N
# 338           3.0        880.0          TA          TA           Y
# 431           2.0        577.0          TA          TA           Y
# 451           2.0        480.0          TA          TA           Y
# 591           2.0        569.0          TA          TA           Y
# 844           2.0        528.0          TA          TA           Y
# 913           2.0        484.0          TA          TA           Y
# 939           2.0        480.0          TA          TA           Y
# 1025          2.0        480.0          TA          TA           Y
# 1244          3.0        644.0          TA          TA           Y
# 1306          2.0        400.0          TA          TA           Y
# 1430          2.0        469.0          TA          TA           Y
# 1434          2.0        562.0          TA          TA           Y
# 1606          2.0        403.0          TA          TA           Y
# 1699          2.0        502.0          TA          TA           Y
# 1815          3.0        928.0          TA          TA           Y
# 1820          2.0        572.0          TA          TA           Y
# 1941          2.0        440.0          TA          TA           Y
#
#       wood_deck_sf  open_porch_sf  enclosed_porch  3ssn_porch  screen_porch  \
# 22             243            142               0           0             0
# 41             216            229               0           0             0
# 86               0             41               0           0             0
# 212              0            121               0           0             0
# 276             32              0               0           0             0
# 338            168            127               0           0             0
# 431              0            211               0           0             0
# 451              0             20               0           0             0
# 591              0            116               0           0             0
# 844              0            102               0           0             0
# 913              0              0             200           0             0
# 939              0            120               0           0             0
# 1025             0            228               0           0             0
# 1244             0             48               0           0             0
# 1306           100              0               0           0             0
# 1430           144            112               0           0             0
# 1434             0              0               0           0             0
# 1606           100             35               0           0             0
# 1699           132              0               0           0             0
# 1815             0            240             200           0             0
# 1820           100              0               0           0             0
# 1941           288             48               0           0             0
#
#       pool_area  misc_val  mo_sold  yr_sold sale_type  saleprice
# 22            0         0        7     2006       New     344133
# 41            0         0        9     2006       New     465000
# 86            0         0        8     2009       WD      184900
# 212           0         0       10     2009       New     225000
# 276           0         0        4     2006       WD      117250
# 338           0         0       12     2007       New     310013
# 431           0         0        3     2008       WD      237000
# 451           0         0        8     2008       WD      247000
# 591           0         0       11     2007       New     199900
# 844           0         0        7     2007       New     207500
# 913           0         0        3     2007       WD      200624
# 939           0         0       12     2008       New     182000
# 1025          0         0        9     2007       New     235876
# 1244          0         0        7     2009       WD      257500
# 1306          0         0       10     2007       WD      165500
# 1430          0         0        4     2008       WD      205000
# 1434          0         0        5     2008       WD      205950
# 1606          0         0        4     2008       WD      176000
# 1699          0         0        9     2007       New     267300
# 1815          0         0        9     2006       New     336820
# 1820          0         0        5     2007       New     181755
# 1941          0         0        5     2010       WD      216500

# %%
#If both mas_vnr_area and mas_vnr_type is missing, then let area be 0 and Type be None
train.loc[(train['mas_vnr_area'].isna()) & (train['mas_vnr_type'].isna()), 'mas_vnr_area'] = 0.0
train.loc[(train['mas_vnr_area'] == 0.0) & (train['mas_vnr_type'].isna()), 'mas_vnr_type'] = 'None'

# %%
#Check
train[(train['mas_vnr_area'].isna()) & (train['mas_vnr_type'].isna())]
# Out:
# Empty DataFrame
# Columns: [ms_subclass, ms_zoning, lot_frontage, lot_area, street, lot_shape, land_contour, utilities, lot_config, land_slope, neighborhood, condition_1, condition_2, bldg_type, house_style, overall_qual, overall_cond, year_built, year_remod/add, roof_style, roof_matl, exterior_1st, exterior_2nd, mas_vnr_type, mas_vnr_area, exter_qual, exter_cond, foundation, bsmt_qual, bsmt_cond, bsmt_exposure, bsmtfin_type_1, bsmtfin_sf_1, bsmtfin_type_2, bsmtfin_sf_2, bsmt_unf_sf, total_bsmt_sf, heating, heating_qc, central_air, electrical, 1st_flr_sf, 2nd_flr_sf, low_qual_fin_sf, gr_liv_area, bsmt_full_bath, bsmt_half_bath, full_bath, half_bath, bedroom_abvgr, kitchen_abvgr, kitchen_qual, totrms_abvgrd, functional, fireplaces, garage_type, garage_yr_blt, garage_finish, garage_cars, garage_area, garage_qual, garage_cond, paved_drive, wood_deck_sf, open_porch_sf, enclosed_porch, 3ssn_porch, screen_porch, pool_area, misc_val, mo_sold, yr_sold, sale_type, saleprice]
# Index: []

# %%
print(f'Number of missing values in bsmt_half_bath: {train.bsmt_half_bath.isna().sum()}')
print(f'% of missing values in bsmt_half_bath: {round(train.bsmt_half_bath.isna().sum()/rows*100,1)}%')
# Out:
# Number of missing values in bsmt_half_bath: 2
# % of missing values in bsmt_half_bath: 0.1%

# %%
#Look at the rows with bsmt half bath is missing
#these are the same 2 rows that bsmt full bath is missing
#since there bsmt details are all NA, we should change this to NA

train[(train['bsmt_half_bath'].isna())]
# Out:
#      ms_subclass ms_zoning  lot_frontage  lot_area street lot_shape  \
# 616           20        RL         123.0     47007   Pave       IR1
# 1327          20        RM          99.0      5940   Pave       IR1
#
#      land_contour utilities lot_config land_slope neighborhood condition_1  \
# 616           Lvl    AllPub     Inside        Gtl      Edwards        Norm
# 1327          Lvl    AllPub        FR3        Gtl      BrkSide       Feedr
#
#      condition_2 bldg_type house_style  overall_qual  overall_cond  \
# 616         Norm      1Fam      1Story             5             7
# 1327        Norm      1Fam      1Story             4             7
#
#       year_built  year_remod/add roof_style roof_matl exterior_1st  \
# 616         1959            1996      Gable   CompShg      Plywood
# 1327        1946            1950      Gable   CompShg      MetalSd
#
#      exterior_2nd mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation  \
# 616       Plywood         None           0.0         TA         TA       Slab
# 1327       CBlock         None           0.0         TA         TA      PConc
#
#      bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1  \
# 616         NA        NA            NA             NA           0.0
# 1327        NA        NA            NA             NA           NaN
#
#      bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf heating  \
# 616              NA           0.0          0.0            0.0    GasA
# 1327             NA           NaN          NaN            NaN    GasA
#
#      heating_qc central_air electrical  1st_flr_sf  2nd_flr_sf  \
# 616          TA           Y      SBrkr        3820           0
# 1327         TA           Y      FuseA         896           0
#
#       low_qual_fin_sf  gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  \
# 616                 0         3820             NaN             NaN          3
# 1327                0          896             NaN             NaN          1
#
#       half_bath  bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd  \
# 616           1              5              1           Ex             11
# 1327          0              2              1           TA              4
#
#      functional  fireplaces garage_type garage_yr_blt garage_finish  \
# 616         Typ           2      Attchd          1959           Unf
# 1327        Typ           0      Detchd          1946           Unf
#
#       garage_cars  garage_area garage_qual garage_cond paved_drive  \
# 616           2.0        624.0          TA          TA           Y
# 1327          1.0        280.0          TA          TA           Y
#
#       wood_deck_sf  open_porch_sf  enclosed_porch  3ssn_porch  screen_porch  \
# 616              0            372               0           0             0
# 1327             0              0               0           0             0
#
#       pool_area  misc_val  mo_sold  yr_sold sale_type  saleprice
# 616           0         0        7     2008       WD      284700
# 1327          0         0        4     2008     ConLD      79000

# %%
print(f'Number of missing values in bsmt_full_bath: {train.bsmt_full_bath.isna().sum()}')
print(f'% of missing values in bsmt_full_bath: {round(train.bsmt_full_bath.isna().sum()/rows*100,1)}%')
# Out:
# Number of missing values in bsmt_full_bath: 2
# % of missing values in bsmt_full_bath: 0.1%

# %%
#Check for null
train.loc[(train['bsmt_half_bath'].isna()), 'bsmt_full_bath'] = 0
train.loc[(train['bsmt_half_bath'].isna()), 'bsmt_half_bath'] = 0

# %%
train[(train['bsmt_half_bath'].isna())]
# Out:
# Empty DataFrame
# Columns: [ms_subclass, ms_zoning, lot_frontage, lot_area, street, lot_shape, land_contour, utilities, lot_config, land_slope, neighborhood, condition_1, condition_2, bldg_type, house_style, overall_qual, overall_cond, year_built, year_remod/add, roof_style, roof_matl, exterior_1st, exterior_2nd, mas_vnr_type, mas_vnr_area, exter_qual, exter_cond, foundation, bsmt_qual, bsmt_cond, bsmt_exposure, bsmtfin_type_1, bsmtfin_sf_1, bsmtfin_type_2, bsmtfin_sf_2, bsmt_unf_sf, total_bsmt_sf, heating, heating_qc, central_air, electrical, 1st_flr_sf, 2nd_flr_sf, low_qual_fin_sf, gr_liv_area, bsmt_full_bath, bsmt_half_bath, full_bath, half_bath, bedroom_abvgr, kitchen_abvgr, kitchen_qual, totrms_abvgrd, functional, fireplaces, garage_type, garage_yr_blt, garage_finish, garage_cars, garage_area, garage_qual, garage_cond, paved_drive, wood_deck_sf, open_porch_sf, enclosed_porch, 3ssn_porch, screen_porch, pool_area, misc_val, mo_sold, yr_sold, sale_type, saleprice]
# Index: []

# %%
print(f'Number of missing values in garage_area: {train.garage_area.isna().sum()}')
print(f'% of missing values in garage_area: {round(train.garage_area.isna().sum()/rows*100,1)}%')
# Out:
# Number of missing values in garage_area: 1
# % of missing values in garage_area: 0.0%

# %%
train[(train['garage_area'].isna())]
#All garage type are NA
# Out:
#      ms_subclass ms_zoning  lot_frontage  lot_area street lot_shape  \
# 1712          70        RM          50.0      9060   Pave       Reg
#
#      land_contour utilities lot_config land_slope neighborhood condition_1  \
# 1712          Lvl    AllPub     Inside        Gtl       IDOTRR        Norm
#
#      condition_2 bldg_type house_style  overall_qual  overall_cond  \
# 1712        Norm      1Fam      2Story             5             6
#
#       year_built  year_remod/add roof_style roof_matl exterior_1st  \
# 1712        1923            1999      Gable   CompShg      Wd Sdng
#
#      exterior_2nd mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation  \
# 1712      Plywood         None           0.0         TA         TA     BrkTil
#
#      bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1  \
# 1712        Gd        TA            No            ALQ         548.0
#
#      bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf heating  \
# 1712            Unf           0.0        311.0          859.0    GasA
#
#      heating_qc central_air electrical  1st_flr_sf  2nd_flr_sf  \
# 1712         Ex           Y      SBrkr         942         886
#
#       low_qual_fin_sf  gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  \
# 1712                0         1828             0.0             0.0          2
#
#       half_bath  bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd  \
# 1712          0              3              1           Gd              6
#
#      functional  fireplaces garage_type garage_yr_blt garage_finish  \
# 1712        Typ           0          NA            NA            NA
#
#       garage_cars  garage_area garage_qual garage_cond paved_drive  \
# 1712          NaN          NaN          NA          NA           Y
#
#       wood_deck_sf  open_porch_sf  enclosed_porch  3ssn_porch  screen_porch  \
# 1712           174              0             212           0             0
#
#       pool_area  misc_val  mo_sold  yr_sold sale_type  saleprice
# 1712          0         0        3     2007       WD      150909

# %%
train.loc[(train['garage_area'].isna()), 'garage_area'] = 0
train[(train['garage_area'].isna())]
# Out:
# Empty DataFrame
# Columns: [ms_subclass, ms_zoning, lot_frontage, lot_area, street, lot_shape, land_contour, utilities, lot_config, land_slope, neighborhood, condition_1, condition_2, bldg_type, house_style, overall_qual, overall_cond, year_built, year_remod/add, roof_style, roof_matl, exterior_1st, exterior_2nd, mas_vnr_type, mas_vnr_area, exter_qual, exter_cond, foundation, bsmt_qual, bsmt_cond, bsmt_exposure, bsmtfin_type_1, bsmtfin_sf_1, bsmtfin_type_2, bsmtfin_sf_2, bsmt_unf_sf, total_bsmt_sf, heating, heating_qc, central_air, electrical, 1st_flr_sf, 2nd_flr_sf, low_qual_fin_sf, gr_liv_area, bsmt_full_bath, bsmt_half_bath, full_bath, half_bath, bedroom_abvgr, kitchen_abvgr, kitchen_qual, totrms_abvgrd, functional, fireplaces, garage_type, garage_yr_blt, garage_finish, garage_cars, garage_area, garage_qual, garage_cond, paved_drive, wood_deck_sf, open_porch_sf, enclosed_porch, 3ssn_porch, screen_porch, pool_area, misc_val, mo_sold, yr_sold, sale_type, saleprice]
# Index: []

# %%
print(f'Number of missing values in total_bsmt_sf: {train.total_bsmt_sf.isna().sum()}')
print(f'% of missing values in total_bsmt_sf: {round(train.total_bsmt_sf.isna().sum()/rows*100,1)}%')
# Out:
# Number of missing values in total_bsmt_sf: 1
# % of missing values in total_bsmt_sf: 0.0%

# %%
train[(train['total_bsmt_sf'].isna())]
# Out:
#      ms_subclass ms_zoning  lot_frontage  lot_area street lot_shape  \
# 1327          20        RM          99.0      5940   Pave       IR1
#
#      land_contour utilities lot_config land_slope neighborhood condition_1  \
# 1327          Lvl    AllPub        FR3        Gtl      BrkSide       Feedr
#
#      condition_2 bldg_type house_style  overall_qual  overall_cond  \
# 1327        Norm      1Fam      1Story             4             7
#
#       year_built  year_remod/add roof_style roof_matl exterior_1st  \
# 1327        1946            1950      Gable   CompShg      MetalSd
#
#      exterior_2nd mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation  \
# 1327       CBlock         None           0.0         TA         TA      PConc
#
#      bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1  \
# 1327        NA        NA            NA             NA           NaN
#
#      bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf heating  \
# 1327             NA           NaN          NaN            NaN    GasA
#
#      heating_qc central_air electrical  1st_flr_sf  2nd_flr_sf  \
# 1327         TA           Y      FuseA         896           0
#
#       low_qual_fin_sf  gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  \
# 1327                0          896             0.0             0.0          1
#
#       half_bath  bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd  \
# 1327          0              2              1           TA              4
#
#      functional  fireplaces garage_type garage_yr_blt garage_finish  \
# 1327        Typ           0      Detchd          1946           Unf
#
#       garage_cars  garage_area garage_qual garage_cond paved_drive  \
# 1327          1.0        280.0          TA          TA           Y
#
#       wood_deck_sf  open_porch_sf  enclosed_porch  3ssn_porch  screen_porch  \
# 1327             0              0               0           0             0
#
#       pool_area  misc_val  mo_sold  yr_sold sale_type  saleprice
# 1327          0         0        4     2008     ConLD      79000

# %%
train.loc[(train['total_bsmt_sf'].isna()), 'total_bsmt_sf'] = 0
train[(train['total_bsmt_sf'].isna())]
# Out:
# Empty DataFrame
# Columns: [ms_subclass, ms_zoning, lot_frontage, lot_area, street, lot_shape, land_contour, utilities, lot_config, land_slope, neighborhood, condition_1, condition_2, bldg_type, house_style, overall_qual, overall_cond, year_built, year_remod/add, roof_style, roof_matl, exterior_1st, exterior_2nd, mas_vnr_type, mas_vnr_area, exter_qual, exter_cond, foundation, bsmt_qual, bsmt_cond, bsmt_exposure, bsmtfin_type_1, bsmtfin_sf_1, bsmtfin_type_2, bsmtfin_sf_2, bsmt_unf_sf, total_bsmt_sf, heating, heating_qc, central_air, electrical, 1st_flr_sf, 2nd_flr_sf, low_qual_fin_sf, gr_liv_area, bsmt_full_bath, bsmt_half_bath, full_bath, half_bath, bedroom_abvgr, kitchen_abvgr, kitchen_qual, totrms_abvgrd, functional, fireplaces, garage_type, garage_yr_blt, garage_finish, garage_cars, garage_area, garage_qual, garage_cond, paved_drive, wood_deck_sf, open_porch_sf, enclosed_porch, 3ssn_porch, screen_porch, pool_area, misc_val, mo_sold, yr_sold, sale_type, saleprice]
# Index: []

# %%
print(f'Number of missing values in bsmt_unf_sf: {train.bsmt_unf_sf.isna().sum()}')
print(f'% of missing values in bsmt_unf_sf: {round(train.bsmt_unf_sf.isna().sum()/rows*100,1)}%')
# Out:
# Number of missing values in bsmt_unf_sf: 1
# % of missing values in bsmt_unf_sf: 0.0%

# %%
train[(train['bsmt_unf_sf'].isna())]
# Out:
#      ms_subclass ms_zoning  lot_frontage  lot_area street lot_shape  \
# 1327          20        RM          99.0      5940   Pave       IR1
#
#      land_contour utilities lot_config land_slope neighborhood condition_1  \
# 1327          Lvl    AllPub        FR3        Gtl      BrkSide       Feedr
#
#      condition_2 bldg_type house_style  overall_qual  overall_cond  \
# 1327        Norm      1Fam      1Story             4             7
#
#       year_built  year_remod/add roof_style roof_matl exterior_1st  \
# 1327        1946            1950      Gable   CompShg      MetalSd
#
#      exterior_2nd mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation  \
# 1327       CBlock         None           0.0         TA         TA      PConc
#
#      bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1  \
# 1327        NA        NA            NA             NA           NaN
#
#      bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf heating  \
# 1327             NA           NaN          NaN            0.0    GasA
#
#      heating_qc central_air electrical  1st_flr_sf  2nd_flr_sf  \
# 1327         TA           Y      FuseA         896           0
#
#       low_qual_fin_sf  gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  \
# 1327                0          896             0.0             0.0          1
#
#       half_bath  bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd  \
# 1327          0              2              1           TA              4
#
#      functional  fireplaces garage_type garage_yr_blt garage_finish  \
# 1327        Typ           0      Detchd          1946           Unf
#
#       garage_cars  garage_area garage_qual garage_cond paved_drive  \
# 1327          1.0        280.0          TA          TA           Y
#
#       wood_deck_sf  open_porch_sf  enclosed_porch  3ssn_porch  screen_porch  \
# 1327             0              0               0           0             0
#
#       pool_area  misc_val  mo_sold  yr_sold sale_type  saleprice
# 1327          0         0        4     2008     ConLD      79000

# %%
train.loc[(train['bsmt_unf_sf'].isna()), 'bsmt_unf_sf'] = 0
train[(train['bsmt_unf_sf'].isna())]
# Out:
# Empty DataFrame
# Columns: [ms_subclass, ms_zoning, lot_frontage, lot_area, street, lot_shape, land_contour, utilities, lot_config, land_slope, neighborhood, condition_1, condition_2, bldg_type, house_style, overall_qual, overall_cond, year_built, year_remod/add, roof_style, roof_matl, exterior_1st, exterior_2nd, mas_vnr_type, mas_vnr_area, exter_qual, exter_cond, foundation, bsmt_qual, bsmt_cond, bsmt_exposure, bsmtfin_type_1, bsmtfin_sf_1, bsmtfin_type_2, bsmtfin_sf_2, bsmt_unf_sf, total_bsmt_sf, heating, heating_qc, central_air, electrical, 1st_flr_sf, 2nd_flr_sf, low_qual_fin_sf, gr_liv_area, bsmt_full_bath, bsmt_half_bath, full_bath, half_bath, bedroom_abvgr, kitchen_abvgr, kitchen_qual, totrms_abvgrd, functional, fireplaces, garage_type, garage_yr_blt, garage_finish, garage_cars, garage_area, garage_qual, garage_cond, paved_drive, wood_deck_sf, open_porch_sf, enclosed_porch, 3ssn_porch, screen_porch, pool_area, misc_val, mo_sold, yr_sold, sale_type, saleprice]
# Index: []

# %%
print(f'Number of missing values in bsmtfin_sf_2: {train.bsmtfin_sf_2.isna().sum()}')
print(f'% of missing values in bsmtfin_sf_2: {round(train.bsmtfin_sf_2.isna().sum()/rows*100,1)}%')
# Out:
# Number of missing values in bsmtfin_sf_2: 1
# % of missing values in bsmtfin_sf_2: 0.0%

# %%
train[(train['bsmtfin_sf_2'].isna())]
# Out:
#      ms_subclass ms_zoning  lot_frontage  lot_area street lot_shape  \
# 1327          20        RM          99.0      5940   Pave       IR1
#
#      land_contour utilities lot_config land_slope neighborhood condition_1  \
# 1327          Lvl    AllPub        FR3        Gtl      BrkSide       Feedr
#
#      condition_2 bldg_type house_style  overall_qual  overall_cond  \
# 1327        Norm      1Fam      1Story             4             7
#
#       year_built  year_remod/add roof_style roof_matl exterior_1st  \
# 1327        1946            1950      Gable   CompShg      MetalSd
#
#      exterior_2nd mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation  \
# 1327       CBlock         None           0.0         TA         TA      PConc
#
#      bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1  \
# 1327        NA        NA            NA             NA           NaN
#
#      bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf heating  \
# 1327             NA           NaN          0.0            0.0    GasA
#
#      heating_qc central_air electrical  1st_flr_sf  2nd_flr_sf  \
# 1327         TA           Y      FuseA         896           0
#
#       low_qual_fin_sf  gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  \
# 1327                0          896             0.0             0.0          1
#
#       half_bath  bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd  \
# 1327          0              2              1           TA              4
#
#      functional  fireplaces garage_type garage_yr_blt garage_finish  \
# 1327        Typ           0      Detchd          1946           Unf
#
#       garage_cars  garage_area garage_qual garage_cond paved_drive  \
# 1327          1.0        280.0          TA          TA           Y
#
#       wood_deck_sf  open_porch_sf  enclosed_porch  3ssn_porch  screen_porch  \
# 1327             0              0               0           0             0
#
#       pool_area  misc_val  mo_sold  yr_sold sale_type  saleprice
# 1327          0         0        4     2008     ConLD      79000

# %%
train.loc[(train['bsmtfin_sf_2'].isna()), 'bsmtfin_sf_2'] = 0
train[(train['bsmtfin_sf_2'].isna())]
# Out:
# Empty DataFrame
# Columns: [ms_subclass, ms_zoning, lot_frontage, lot_area, street, lot_shape, land_contour, utilities, lot_config, land_slope, neighborhood, condition_1, condition_2, bldg_type, house_style, overall_qual, overall_cond, year_built, year_remod/add, roof_style, roof_matl, exterior_1st, exterior_2nd, mas_vnr_type, mas_vnr_area, exter_qual, exter_cond, foundation, bsmt_qual, bsmt_cond, bsmt_exposure, bsmtfin_type_1, bsmtfin_sf_1, bsmtfin_type_2, bsmtfin_sf_2, bsmt_unf_sf, total_bsmt_sf, heating, heating_qc, central_air, electrical, 1st_flr_sf, 2nd_flr_sf, low_qual_fin_sf, gr_liv_area, bsmt_full_bath, bsmt_half_bath, full_bath, half_bath, bedroom_abvgr, kitchen_abvgr, kitchen_qual, totrms_abvgrd, functional, fireplaces, garage_type, garage_yr_blt, garage_finish, garage_cars, garage_area, garage_qual, garage_cond, paved_drive, wood_deck_sf, open_porch_sf, enclosed_porch, 3ssn_porch, screen_porch, pool_area, misc_val, mo_sold, yr_sold, sale_type, saleprice]
# Index: []

# %%
print(f'Number of missing values in bsmtfin_sf_1: {train.bsmtfin_sf_1.isna().sum()}')
print(f'% of missing values in bsmtfin_sf_1: {round(train.bsmtfin_sf_1.isna().sum()/rows*100,1)}%')
# Out:
# Number of missing values in bsmtfin_sf_1: 1
# % of missing values in bsmtfin_sf_1: 0.0%

# %%
train[(train['bsmtfin_sf_1'].isna())]
# Out:
#      ms_subclass ms_zoning  lot_frontage  lot_area street lot_shape  \
# 1327          20        RM          99.0      5940   Pave       IR1
#
#      land_contour utilities lot_config land_slope neighborhood condition_1  \
# 1327          Lvl    AllPub        FR3        Gtl      BrkSide       Feedr
#
#      condition_2 bldg_type house_style  overall_qual  overall_cond  \
# 1327        Norm      1Fam      1Story             4             7
#
#       year_built  year_remod/add roof_style roof_matl exterior_1st  \
# 1327        1946            1950      Gable   CompShg      MetalSd
#
#      exterior_2nd mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation  \
# 1327       CBlock         None           0.0         TA         TA      PConc
#
#      bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1  \
# 1327        NA        NA            NA             NA           NaN
#
#      bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf heating  \
# 1327             NA           0.0          0.0            0.0    GasA
#
#      heating_qc central_air electrical  1st_flr_sf  2nd_flr_sf  \
# 1327         TA           Y      FuseA         896           0
#
#       low_qual_fin_sf  gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  \
# 1327                0          896             0.0             0.0          1
#
#       half_bath  bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd  \
# 1327          0              2              1           TA              4
#
#      functional  fireplaces garage_type garage_yr_blt garage_finish  \
# 1327        Typ           0      Detchd          1946           Unf
#
#       garage_cars  garage_area garage_qual garage_cond paved_drive  \
# 1327          1.0        280.0          TA          TA           Y
#
#       wood_deck_sf  open_porch_sf  enclosed_porch  3ssn_porch  screen_porch  \
# 1327             0              0               0           0             0
#
#       pool_area  misc_val  mo_sold  yr_sold sale_type  saleprice
# 1327          0         0        4     2008     ConLD      79000

# %%
train.loc[(train['bsmtfin_sf_1'].isna()), 'bsmtfin_sf_1'] = 0
train[(train['bsmtfin_sf_1'].isna())]
# Out:
# Empty DataFrame
# Columns: [ms_subclass, ms_zoning, lot_frontage, lot_area, street, lot_shape, land_contour, utilities, lot_config, land_slope, neighborhood, condition_1, condition_2, bldg_type, house_style, overall_qual, overall_cond, year_built, year_remod/add, roof_style, roof_matl, exterior_1st, exterior_2nd, mas_vnr_type, mas_vnr_area, exter_qual, exter_cond, foundation, bsmt_qual, bsmt_cond, bsmt_exposure, bsmtfin_type_1, bsmtfin_sf_1, bsmtfin_type_2, bsmtfin_sf_2, bsmt_unf_sf, total_bsmt_sf, heating, heating_qc, central_air, electrical, 1st_flr_sf, 2nd_flr_sf, low_qual_fin_sf, gr_liv_area, bsmt_full_bath, bsmt_half_bath, full_bath, half_bath, bedroom_abvgr, kitchen_abvgr, kitchen_qual, totrms_abvgrd, functional, fireplaces, garage_type, garage_yr_blt, garage_finish, garage_cars, garage_area, garage_qual, garage_cond, paved_drive, wood_deck_sf, open_porch_sf, enclosed_porch, 3ssn_porch, screen_porch, pool_area, misc_val, mo_sold, yr_sold, sale_type, saleprice]
# Index: []

# %%
print(f'Number of missing values in garage_cars: {train.garage_cars.isna().sum()}')
print(f'% of missing values in garage_cars: {round(train.garage_cars.isna().sum()/rows*100,1)}%')
# Out:
# Number of missing values in garage_cars: 1
# % of missing values in garage_cars: 0.0%

# %%
train[(train['garage_cars'].isna())]
# Out:
#      ms_subclass ms_zoning  lot_frontage  lot_area street lot_shape  \
# 1712          70        RM          50.0      9060   Pave       Reg
#
#      land_contour utilities lot_config land_slope neighborhood condition_1  \
# 1712          Lvl    AllPub     Inside        Gtl       IDOTRR        Norm
#
#      condition_2 bldg_type house_style  overall_qual  overall_cond  \
# 1712        Norm      1Fam      2Story             5             6
#
#       year_built  year_remod/add roof_style roof_matl exterior_1st  \
# 1712        1923            1999      Gable   CompShg      Wd Sdng
#
#      exterior_2nd mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation  \
# 1712      Plywood         None           0.0         TA         TA     BrkTil
#
#      bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1  \
# 1712        Gd        TA            No            ALQ         548.0
#
#      bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf heating  \
# 1712            Unf           0.0        311.0          859.0    GasA
#
#      heating_qc central_air electrical  1st_flr_sf  2nd_flr_sf  \
# 1712         Ex           Y      SBrkr         942         886
#
#       low_qual_fin_sf  gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  \
# 1712                0         1828             0.0             0.0          2
#
#       half_bath  bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd  \
# 1712          0              3              1           Gd              6
#
#      functional  fireplaces garage_type garage_yr_blt garage_finish  \
# 1712        Typ           0          NA            NA            NA
#
#       garage_cars  garage_area garage_qual garage_cond paved_drive  \
# 1712          NaN          0.0          NA          NA           Y
#
#       wood_deck_sf  open_porch_sf  enclosed_porch  3ssn_porch  screen_porch  \
# 1712           174              0             212           0             0
#
#       pool_area  misc_val  mo_sold  yr_sold sale_type  saleprice
# 1712          0         0        3     2007       WD      150909

# %%
train.loc[(train['garage_cars'].isna()), 'garage_cars'] = 0
train[(train['garage_cars'].isna())]
# Out:
# Empty DataFrame
# Columns: [ms_subclass, ms_zoning, lot_frontage, lot_area, street, lot_shape, land_contour, utilities, lot_config, land_slope, neighborhood, condition_1, condition_2, bldg_type, house_style, overall_qual, overall_cond, year_built, year_remod/add, roof_style, roof_matl, exterior_1st, exterior_2nd, mas_vnr_type, mas_vnr_area, exter_qual, exter_cond, foundation, bsmt_qual, bsmt_cond, bsmt_exposure, bsmtfin_type_1, bsmtfin_sf_1, bsmtfin_type_2, bsmtfin_sf_2, bsmt_unf_sf, total_bsmt_sf, heating, heating_qc, central_air, electrical, 1st_flr_sf, 2nd_flr_sf, low_qual_fin_sf, gr_liv_area, bsmt_full_bath, bsmt_half_bath, full_bath, half_bath, bedroom_abvgr, kitchen_abvgr, kitchen_qual, totrms_abvgrd, functional, fireplaces, garage_type, garage_yr_blt, garage_finish, garage_cars, garage_area, garage_qual, garage_cond, paved_drive, wood_deck_sf, open_porch_sf, enclosed_porch, 3ssn_porch, screen_porch, pool_area, misc_val, mo_sold, yr_sold, sale_type, saleprice]
# Index: []

# %%
#Check for missing data again
train.isnull().sum().sort_values(ascending=False)
# Out:
# ms_subclass        0
# garage_type        0
# functional         0
# totrms_abvgrd      0
# kitchen_qual       0
# kitchen_abvgr      0
# bedroom_abvgr      0
# half_bath          0
# full_bath          0
# bsmt_half_bath     0
# bsmt_full_bath     0
# gr_liv_area        0
# low_qual_fin_sf    0
# 2nd_flr_sf         0
# 1st_flr_sf         0
# electrical         0
# central_air        0
# fireplaces         0
# garage_yr_blt      0
# ms_zoning          0
# garage_finish      0
# sale_type          0
# yr_sold            0
# mo_sold            0
# misc_val           0
# pool_area          0
# screen_porch       0
# 3ssn_porch         0
# enclosed_porch     0
# open_porch_sf      0
# wood_deck_sf       0
# paved_drive        0
# garage_cond        0
# garage_qual        0
# garage_area        0
# garage_cars        0
# heating_qc         0
# heating            0
# total_bsmt_sf      0
# bsmt_unf_sf        0
# overall_cond       0
# overall_qual       0
# house_style        0
# bldg_type          0
# condition_2        0
# condition_1        0
# neighborhood       0
# land_slope         0
# lot_config         0
# utilities          0
# land_contour       0
# lot_shape          0
# street             0
# lot_area           0
# lot_frontage       0
# year_built         0
# year_remod/add     0
# roof_style         0
# bsmt_qual          0
# bsmtfin_sf_2       0
# bsmtfin_type_2     0
# bsmtfin_sf_1       0
# bsmtfin_type_1     0
# bsmt_exposure      0
# bsmt_cond          0
# foundation         0
# roof_matl          0
# exter_cond         0
# exter_qual         0
# mas_vnr_area       0
# mas_vnr_type       0
# exterior_2nd       0
# exterior_1st       0
# saleprice          0
# dtype: int64

# %%
#Check the shape
train.shape
# Out:
# (2051, 74)

# %%
#To understand the data
train.describe()
# Out:
#        lot_frontage       lot_area  overall_qual  overall_cond   year_built  \
# count   2051.000000    2051.000000   2051.000000   2051.000000  2051.000000
# mean      68.844988   10065.208191      6.112140      5.562165  1971.708922
# std       21.624350    6742.488909      1.426271      1.104497    30.177889
# min       21.000000    1300.000000      1.000000      1.000000  1872.000000
# 25%       59.000000    7500.000000      5.000000      5.000000  1953.500000
# 50%       66.759571    9430.000000      6.000000      5.000000  1974.000000
# 75%       80.000000   11513.500000      7.000000      6.000000  2001.000000
# max      313.000000  159000.000000     10.000000      9.000000  2010.000000
#
#        year_remod/add  mas_vnr_area  bsmtfin_sf_1  bsmtfin_sf_2  bsmt_unf_sf  \
# count     2051.000000   2051.000000   2051.000000   2051.000000  2051.000000
# mean      1984.190151     98.626524    442.084837     47.935641   567.451487
# std         21.036250    174.324690    461.195041    164.964052   445.022846
# min       1950.000000      0.000000      0.000000      0.000000     0.000000
# 25%       1964.500000      0.000000      0.000000      0.000000   220.000000
# 50%       1993.000000      0.000000    368.000000      0.000000   474.000000
# 75%       2004.000000    159.000000    733.500000      0.000000   811.000000
# max       2010.000000   1600.000000   5644.000000   1474.000000  2336.000000
#
#        total_bsmt_sf   1st_flr_sf   2nd_flr_sf  low_qual_fin_sf  gr_liv_area  \
# count    2051.000000  2051.000000  2051.000000      2051.000000  2051.000000
# mean     1057.471965  1164.488055   329.329108         5.512921  1499.330083
# std       449.908003   396.446923   425.671046        51.068870   500.447829
# min         0.000000   334.000000     0.000000         0.000000   334.000000
# 25%       793.000000   879.500000     0.000000         0.000000  1129.000000
# 50%       994.000000  1093.000000     0.000000         0.000000  1444.000000
# 75%      1318.500000  1405.000000   692.500000         0.000000  1728.500000
# max      6110.000000  5095.000000  1862.000000      1064.000000  5642.000000
#
#        bsmt_full_bath  bsmt_half_bath    full_bath    half_bath  \
# count     2051.000000     2051.000000  2051.000000  2051.000000
# mean         0.427109        0.063384     1.577279     0.371039
# std          0.522589        0.251590     0.549279     0.501043
# min          0.000000        0.000000     0.000000     0.000000
# 25%          0.000000        0.000000     1.000000     0.000000
# 50%          0.000000        0.000000     2.000000     0.000000
# 75%          1.000000        0.000000     2.000000     1.000000
# max          3.000000        2.000000     4.000000     2.000000
#
#        bedroom_abvgr  kitchen_abvgr  totrms_abvgrd   fireplaces  garage_cars  \
# count    2051.000000    2051.000000    2051.000000  2051.000000  2051.000000
# mean        2.843491       1.042906       6.435885     0.590931     1.775719
# std         0.826618       0.209790       1.560225     0.638516     0.765357
# min         0.000000       0.000000       2.000000     0.000000     0.000000
# 25%         2.000000       1.000000       5.000000     0.000000     1.000000
# 50%         3.000000       1.000000       6.000000     1.000000     2.000000
# 75%         3.000000       1.000000       7.000000     1.000000     2.000000
# max         8.000000       3.000000      15.000000     4.000000     5.000000
#
#        garage_area  wood_deck_sf  open_porch_sf  enclosed_porch   3ssn_porch  \
# count  2051.000000   2051.000000    2051.000000     2051.000000  2051.000000
# mean    473.440761     93.833740      47.556802       22.571916     2.591419
# std     216.135102    128.549416      66.747241       59.845110    25.229615
# min       0.000000      0.000000       0.000000        0.000000     0.000000
# 25%     319.000000      0.000000       0.000000        0.000000     0.000000
# 50%     480.000000      0.000000      27.000000        0.000000     0.000000
# 75%     576.000000    168.000000      70.000000        0.000000     0.000000
# max    1418.000000   1424.000000     547.000000      432.000000   508.000000
#
#        screen_porch    pool_area      misc_val      mo_sold      yr_sold  \
# count   2051.000000  2051.000000   2051.000000  2051.000000  2051.000000
# mean      16.511458     2.397855     51.574354     6.219893  2007.775719
# std       57.374204    37.782570    573.393985     2.744736     1.312014
# min        0.000000     0.000000      0.000000     1.000000  2006.000000
# 25%        0.000000     0.000000      0.000000     4.000000  2007.000000
# 50%        0.000000     0.000000      0.000000     6.000000  2008.000000
# 75%        0.000000     0.000000      0.000000     8.000000  2009.000000
# max      490.000000   800.000000  17000.000000    12.000000  2010.000000
#
#            saleprice
# count    2051.000000
# mean   181469.701609
# std     79258.659352
# min     12789.000000
# 25%    129825.000000
# 50%    162500.000000
# 75%    214000.000000
# max    611657.000000

# %% [markdown]
# # 3 EDA

# %% [markdown]
# ## 3.1 Summary Statistics

# %%
#split data columns into numerical and categorical
train_num = train.select_dtypes(exclude='object')
train_cat = train.select_dtypes(include='object')

#Put the columns into a list
list_num = list(train_num)
list_cat = list(train_cat)

#Check the shapes
train.shape, train_num.shape, train_cat.shape
# Out:
# ((2051, 74), (2051, 35), (2051, 39))

# %%
#Check the correlation matrix (for numerical)
#Only look at the correlation with saleprice
correlation_with_saleprice = pd.DataFrame(train_num.corr().tail(1).T).sort_values(by='saleprice', ascending=False)
correlation_with_saleprice
# Out:
#                  saleprice
# saleprice         1.000000
# overall_qual      0.800207
# gr_liv_area       0.697038
# garage_area       0.649897
# garage_cars       0.647781
# total_bsmt_sf     0.629303
# 1st_flr_sf        0.618486
# year_built        0.571849
# year_remod/add    0.550370
# full_bath         0.537969
# totrms_abvgrd     0.504014
# mas_vnr_area      0.503579
# fireplaces        0.471093
# bsmtfin_sf_1      0.423856
# open_porch_sf     0.333476
# wood_deck_sf      0.326490
# lot_frontage      0.319202
# lot_area          0.296566
# bsmt_full_bath    0.283332
# half_bath         0.283001
# 2nd_flr_sf        0.248452
# bsmt_unf_sf       0.190861
# bedroom_abvgr     0.137067
# screen_porch      0.134581
# 3ssn_porch        0.048732
# mo_sold           0.032735
# pool_area         0.023106
# bsmtfin_sf_2      0.016432
# misc_val         -0.007375
# yr_sold          -0.015203
# low_qual_fin_sf  -0.041594
# bsmt_half_bath   -0.045290
# overall_cond     -0.097019
# kitchen_abvgr    -0.125444
# enclosed_porch   -0.135656

# %%
#Correlation > 0.5
correlation_with_saleprice_num_strong = correlation_with_saleprice.loc[correlation_with_saleprice['saleprice']>0.5,:]
correlation_with_saleprice_num_strong
# Out:
#                 saleprice
# saleprice        1.000000
# overall_qual     0.800207
# gr_liv_area      0.697038
# garage_area      0.649897
# garage_cars      0.647781
# total_bsmt_sf    0.629303
# 1st_flr_sf       0.618486
# year_built       0.571849
# year_remod/add   0.550370
# full_bath        0.537969
# totrms_abvgrd    0.504014
# mas_vnr_area     0.503579

# %%
#Check correlation using heatmap (for numerical data)
plt.figure(figsize=(25,18))
sns.heatmap(train_num.corr(),annot=True,mask=np.triu(train_num.corr()), cmap='coolwarm');

# %%
#function to create subplots
def subplots(df, list_of_columns, kind='bar',type_of='cat'):
    fig, ax = plt.subplots(nrows=8, ncols=5, figsize=(20,30)) 
    ax = ax.ravel() #ravel() functions returns contiguous flattened array(1D array with all the input-array elements and with the same type as it)
    for i, column in enumerate(list_of_columns): 
        if (kind == 'scatter') & (type_of == 'num'):
            df.plot(y='saleprice', x=column, kind=kind, ax=ax[i])
        elif (kind == 'box') & (type_of == 'cat'):
            sns.boxplot(x=column,y='saleprice',data=train, ax=ax[i])
        elif type_of == 'num':
            df[column].plot(kind=kind, ax=ax[i])
        else:
            df[column].value_counts().plot(kind=kind, ax=ax[i])
        for i, column in enumerate(list_of_columns):
            ax[i].set_title(column, fontsize=14)        
        plt.subplots_adjust(hspace=1.0,wspace=0.8)

# %%
#Plot for numerical data
subplots(train_num,list_num,kind='scatter', type_of='num');

# %% [markdown]
# Outliers:
# mas_vnr_area: one above 1500
#
# bsmtfin_sf_1: 2 above 4000
#
# bsmtfin_sf_2: 2 above 1200
#
# total_bsmt_sf: 2 above 4000
#
# 1st_flr_sf: 2 above 4000
#
# gr_liv_area: 2 above 4000
#
# 3ssn_porch: 2 above 400
#
# misc_valL 2 above 10k

# %%
#mas_vnr_area: one above 1500
train[(train['mas_vnr_area'] > 1500)]
# Out:
#      ms_subclass ms_zoning  lot_frontage  lot_area street lot_shape  \
# 1409          60        FV          66.0      7399   Pave       IR1
#
#      land_contour utilities lot_config land_slope neighborhood condition_1  \
# 1409          Lvl    AllPub     Inside        Gtl      Somerst        Norm
#
#      condition_2 bldg_type house_style  overall_qual  overall_cond  \
# 1409        Norm      1Fam      2Story             7             5
#
#       year_built  year_remod/add roof_style roof_matl exterior_1st  \
# 1409        1997            1998        Hip   CompShg      VinylSd
#
#      exterior_2nd mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation  \
# 1409      VinylSd      BrkFace        1600.0         Gd         TA      PConc
#
#      bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1  \
# 1409        Gd        TA            No            BLQ         649.0
#
#      bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf heating  \
# 1409            Unf           0.0        326.0          975.0    GasA
#
#      heating_qc central_air electrical  1st_flr_sf  2nd_flr_sf  \
# 1409         Ex           Y      SBrkr         975         975
#
#       low_qual_fin_sf  gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  \
# 1409                0         1950             0.0             0.0          2
#
#       half_bath  bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd  \
# 1409          1              3              1           Gd              7
#
#      functional  fireplaces garage_type garage_yr_blt garage_finish  \
# 1409        Typ           1      Detchd          1997           RFn
#
#       garage_cars  garage_area garage_qual garage_cond paved_drive  \
# 1409          2.0        576.0          TA          TA           Y
#
#       wood_deck_sf  open_porch_sf  enclosed_porch  3ssn_porch  screen_porch  \
# 1409             0             10               0           0           198
#
#       pool_area  misc_val  mo_sold  yr_sold sale_type  saleprice
# 1409          0         0        6     2007       WD      239000

# %%
#Drop and check
train.drop(train[train['mas_vnr_area'] > 1500].index, inplace = True)
train[(train['mas_vnr_area'] > 1500)]
# Out:
# Empty DataFrame
# Columns: [ms_subclass, ms_zoning, lot_frontage, lot_area, street, lot_shape, land_contour, utilities, lot_config, land_slope, neighborhood, condition_1, condition_2, bldg_type, house_style, overall_qual, overall_cond, year_built, year_remod/add, roof_style, roof_matl, exterior_1st, exterior_2nd, mas_vnr_type, mas_vnr_area, exter_qual, exter_cond, foundation, bsmt_qual, bsmt_cond, bsmt_exposure, bsmtfin_type_1, bsmtfin_sf_1, bsmtfin_type_2, bsmtfin_sf_2, bsmt_unf_sf, total_bsmt_sf, heating, heating_qc, central_air, electrical, 1st_flr_sf, 2nd_flr_sf, low_qual_fin_sf, gr_liv_area, bsmt_full_bath, bsmt_half_bath, full_bath, half_bath, bedroom_abvgr, kitchen_abvgr, kitchen_qual, totrms_abvgrd, functional, fireplaces, garage_type, garage_yr_blt, garage_finish, garage_cars, garage_area, garage_qual, garage_cond, paved_drive, wood_deck_sf, open_porch_sf, enclosed_porch, 3ssn_porch, screen_porch, pool_area, misc_val, mo_sold, yr_sold, sale_type, saleprice]
# Index: []

# %%
#bsmtfin_sf_1: 2 above 4000
train[(train['bsmtfin_sf_1'] > 4000)]
# Out:
#      ms_subclass ms_zoning  lot_frontage  lot_area street lot_shape  \
# 960           60        RL         313.0     63887   Pave       IR3
# 1885          20        RL         128.0     39290   Pave       IR1
#
#      land_contour utilities lot_config land_slope neighborhood condition_1  \
# 960           Bnk    AllPub     Corner        Gtl      Edwards       Feedr
# 1885          Bnk    AllPub     Inside        Gtl      Edwards        Norm
#
#      condition_2 bldg_type house_style  overall_qual  overall_cond  \
# 960         Norm      1Fam      2Story            10             5
# 1885        Norm      1Fam      1Story            10             5
#
#       year_built  year_remod/add roof_style roof_matl exterior_1st  \
# 960         2008            2008        Hip   ClyTile       Stucco
# 1885        2008            2009        Hip   CompShg      CemntBd
#
#      exterior_2nd mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation  \
# 960        Stucco        Stone         796.0         Ex         TA      PConc
# 1885      CmentBd        Stone        1224.0         Ex         TA      PConc
#
#      bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1  \
# 960         Ex        TA            Gd            GLQ        5644.0
# 1885        Ex        TA            Gd            GLQ        4010.0
#
#      bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf heating  \
# 960             Unf           0.0        466.0         6110.0    GasA
# 1885            Unf           0.0       1085.0         5095.0    GasA
#
#      heating_qc central_air electrical  1st_flr_sf  2nd_flr_sf  \
# 960          Ex           Y      SBrkr        4692         950
# 1885         Ex           Y      SBrkr        5095           0
#
#       low_qual_fin_sf  gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  \
# 960                 0         5642             2.0             0.0          2
# 1885                0         5095             1.0             1.0          2
#
#       half_bath  bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd  \
# 960           1              3              1           Ex             12
# 1885          1              2              1           Ex             15
#
#      functional  fireplaces garage_type garage_yr_blt garage_finish  \
# 960         Typ           3      Attchd          2008           Fin
# 1885        Typ           2      Attchd          2008           Fin
#
#       garage_cars  garage_area garage_qual garage_cond paved_drive  \
# 960           2.0       1418.0          TA          TA           Y
# 1885          3.0       1154.0          TA          TA           Y
#
#       wood_deck_sf  open_porch_sf  enclosed_porch  3ssn_porch  screen_porch  \
# 960            214            292               0           0             0
# 1885           546            484               0           0             0
#
#       pool_area  misc_val  mo_sold  yr_sold sale_type  saleprice
# 960         480         0        1     2008       New     160000
# 1885          0     17000       10     2007       New     183850

# %%
#Drop and check
train.drop(train[train['bsmtfin_sf_1'] > 4000].index, inplace = True)
train[(train['bsmtfin_sf_1'] > 4000)]
# Out:
# Empty DataFrame
# Columns: [ms_subclass, ms_zoning, lot_frontage, lot_area, street, lot_shape, land_contour, utilities, lot_config, land_slope, neighborhood, condition_1, condition_2, bldg_type, house_style, overall_qual, overall_cond, year_built, year_remod/add, roof_style, roof_matl, exterior_1st, exterior_2nd, mas_vnr_type, mas_vnr_area, exter_qual, exter_cond, foundation, bsmt_qual, bsmt_cond, bsmt_exposure, bsmtfin_type_1, bsmtfin_sf_1, bsmtfin_type_2, bsmtfin_sf_2, bsmt_unf_sf, total_bsmt_sf, heating, heating_qc, central_air, electrical, 1st_flr_sf, 2nd_flr_sf, low_qual_fin_sf, gr_liv_area, bsmt_full_bath, bsmt_half_bath, full_bath, half_bath, bedroom_abvgr, kitchen_abvgr, kitchen_qual, totrms_abvgrd, functional, fireplaces, garage_type, garage_yr_blt, garage_finish, garage_cars, garage_area, garage_qual, garage_cond, paved_drive, wood_deck_sf, open_porch_sf, enclosed_porch, 3ssn_porch, screen_porch, pool_area, misc_val, mo_sold, yr_sold, sale_type, saleprice]
# Index: []

# %%
#bsmtfin_sf_2: 2 above 1200
train[(train['bsmtfin_sf_2'] > 1200)]
# Out:
#      ms_subclass ms_zoning  lot_frontage  lot_area street lot_shape  \
# 770           60        RL          86.0     10380   Pave       IR1
# 1692          60        RL         114.0     17242   Pave       IR1
#
#      land_contour utilities lot_config land_slope neighborhood condition_1  \
# 770           Lvl    AllPub     Inside        Gtl      SawyerW        Norm
# 1692          Lvl    AllPub     Inside        Gtl      NoRidge        Norm
#
#      condition_2 bldg_type house_style  overall_qual  overall_cond  \
# 770         Norm      1Fam      2Story             7             5
# 1692        Norm      1Fam      2Story             9             5
#
#       year_built  year_remod/add roof_style roof_matl exterior_1st  \
# 770         1986            1987      Gable   CompShg      Plywood
# 1692        1993            1994        Hip   CompShg      MetalSd
#
#      exterior_2nd mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation  \
# 770       Plywood      BrkFace         172.0         Gd         TA     CBlock
# 1692      MetalSd      BrkFace         738.0         Gd         Gd      PConc
#
#      bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1  \
# 770         TA        TA            Gd            LwQ          28.0
# 1692        Ex        TA            Gd            Rec         292.0
#
#      bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf heating  \
# 770             ALQ        1474.0          0.0         1502.0    GasA
# 1692            GLQ        1393.0         48.0         1733.0    GasA
#
#      heating_qc central_air electrical  1st_flr_sf  2nd_flr_sf  \
# 770          Ex           Y      SBrkr        1553        1177
# 1692         Ex           Y      SBrkr        1933        1567
#
#       low_qual_fin_sf  gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  \
# 770                 0         2730             1.0             0.0          2
# 1692                0         3500             1.0             0.0          3
#
#       half_bath  bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd  \
# 770           1              4              1           Gd              8
# 1692          1              4              1           Ex             11
#
#      functional  fireplaces garage_type garage_yr_blt garage_finish  \
# 770         Typ           1      Attchd          1987           Fin
# 1692        Typ           1      Attchd          1993           RFn
#
#       garage_cars  garage_area garage_qual garage_cond paved_drive  \
# 770           2.0        576.0          TA          TA           Y
# 1692          3.0        959.0          TA          TA           Y
#
#       wood_deck_sf  open_porch_sf  enclosed_porch  3ssn_porch  screen_porch  \
# 770            201             96               0           0             0
# 1692           870             86               0           0           210
#
#       pool_area  misc_val  mo_sold  yr_sold sale_type  saleprice
# 770           0         0        8     2007       WD      301000
# 1692          0         0        5     2006       WD      584500

# %%
#Drop and check
train.drop(train[train['bsmtfin_sf_2'] > 1200].index, inplace = True)
train[(train['bsmtfin_sf_2'] > 1200)]
# Out:
# Empty DataFrame
# Columns: [ms_subclass, ms_zoning, lot_frontage, lot_area, street, lot_shape, land_contour, utilities, lot_config, land_slope, neighborhood, condition_1, condition_2, bldg_type, house_style, overall_qual, overall_cond, year_built, year_remod/add, roof_style, roof_matl, exterior_1st, exterior_2nd, mas_vnr_type, mas_vnr_area, exter_qual, exter_cond, foundation, bsmt_qual, bsmt_cond, bsmt_exposure, bsmtfin_type_1, bsmtfin_sf_1, bsmtfin_type_2, bsmtfin_sf_2, bsmt_unf_sf, total_bsmt_sf, heating, heating_qc, central_air, electrical, 1st_flr_sf, 2nd_flr_sf, low_qual_fin_sf, gr_liv_area, bsmt_full_bath, bsmt_half_bath, full_bath, half_bath, bedroom_abvgr, kitchen_abvgr, kitchen_qual, totrms_abvgrd, functional, fireplaces, garage_type, garage_yr_blt, garage_finish, garage_cars, garage_area, garage_qual, garage_cond, paved_drive, wood_deck_sf, open_porch_sf, enclosed_porch, 3ssn_porch, screen_porch, pool_area, misc_val, mo_sold, yr_sold, sale_type, saleprice]
# Index: []

# %%
#total_bsmt_sf: 2 above 4000
train[(train['total_bsmt_sf'] > 4000)]
# Out:
# Empty DataFrame
# Columns: [ms_subclass, ms_zoning, lot_frontage, lot_area, street, lot_shape, land_contour, utilities, lot_config, land_slope, neighborhood, condition_1, condition_2, bldg_type, house_style, overall_qual, overall_cond, year_built, year_remod/add, roof_style, roof_matl, exterior_1st, exterior_2nd, mas_vnr_type, mas_vnr_area, exter_qual, exter_cond, foundation, bsmt_qual, bsmt_cond, bsmt_exposure, bsmtfin_type_1, bsmtfin_sf_1, bsmtfin_type_2, bsmtfin_sf_2, bsmt_unf_sf, total_bsmt_sf, heating, heating_qc, central_air, electrical, 1st_flr_sf, 2nd_flr_sf, low_qual_fin_sf, gr_liv_area, bsmt_full_bath, bsmt_half_bath, full_bath, half_bath, bedroom_abvgr, kitchen_abvgr, kitchen_qual, totrms_abvgrd, functional, fireplaces, garage_type, garage_yr_blt, garage_finish, garage_cars, garage_area, garage_qual, garage_cond, paved_drive, wood_deck_sf, open_porch_sf, enclosed_porch, 3ssn_porch, screen_porch, pool_area, misc_val, mo_sold, yr_sold, sale_type, saleprice]
# Index: []

# %%
#1st_flr_sf: 2 above 4000
train[(train['1st_flr_sf'] > 4000)]
# Out:
# Empty DataFrame
# Columns: [ms_subclass, ms_zoning, lot_frontage, lot_area, street, lot_shape, land_contour, utilities, lot_config, land_slope, neighborhood, condition_1, condition_2, bldg_type, house_style, overall_qual, overall_cond, year_built, year_remod/add, roof_style, roof_matl, exterior_1st, exterior_2nd, mas_vnr_type, mas_vnr_area, exter_qual, exter_cond, foundation, bsmt_qual, bsmt_cond, bsmt_exposure, bsmtfin_type_1, bsmtfin_sf_1, bsmtfin_type_2, bsmtfin_sf_2, bsmt_unf_sf, total_bsmt_sf, heating, heating_qc, central_air, electrical, 1st_flr_sf, 2nd_flr_sf, low_qual_fin_sf, gr_liv_area, bsmt_full_bath, bsmt_half_bath, full_bath, half_bath, bedroom_abvgr, kitchen_abvgr, kitchen_qual, totrms_abvgrd, functional, fireplaces, garage_type, garage_yr_blt, garage_finish, garage_cars, garage_area, garage_qual, garage_cond, paved_drive, wood_deck_sf, open_porch_sf, enclosed_porch, 3ssn_porch, screen_porch, pool_area, misc_val, mo_sold, yr_sold, sale_type, saleprice]
# Index: []

# %%
#gr_liv_area: 2 above 4000
train[(train['gr_liv_area'] > 4000)]
# Out:
# Empty DataFrame
# Columns: [ms_subclass, ms_zoning, lot_frontage, lot_area, street, lot_shape, land_contour, utilities, lot_config, land_slope, neighborhood, condition_1, condition_2, bldg_type, house_style, overall_qual, overall_cond, year_built, year_remod/add, roof_style, roof_matl, exterior_1st, exterior_2nd, mas_vnr_type, mas_vnr_area, exter_qual, exter_cond, foundation, bsmt_qual, bsmt_cond, bsmt_exposure, bsmtfin_type_1, bsmtfin_sf_1, bsmtfin_type_2, bsmtfin_sf_2, bsmt_unf_sf, total_bsmt_sf, heating, heating_qc, central_air, electrical, 1st_flr_sf, 2nd_flr_sf, low_qual_fin_sf, gr_liv_area, bsmt_full_bath, bsmt_half_bath, full_bath, half_bath, bedroom_abvgr, kitchen_abvgr, kitchen_qual, totrms_abvgrd, functional, fireplaces, garage_type, garage_yr_blt, garage_finish, garage_cars, garage_area, garage_qual, garage_cond, paved_drive, wood_deck_sf, open_porch_sf, enclosed_porch, 3ssn_porch, screen_porch, pool_area, misc_val, mo_sold, yr_sold, sale_type, saleprice]
# Index: []

# %%
#3ssn_porch: 2 above 400
train[(train['3ssn_porch'] > 400)]
# Out:
#      ms_subclass ms_zoning  lot_frontage  lot_area street lot_shape  \
# 892           20        RL         100.0     10175   Pave       IR1
# 1219          20        RL          99.0     11851   Pave       Reg
#
#      land_contour utilities lot_config land_slope neighborhood condition_1  \
# 892           Lvl    AllPub     Inside        Gtl        NAmes        Norm
# 1219          Lvl    AllPub     Corner        Gtl      Gilbert        Norm
#
#      condition_2 bldg_type house_style  overall_qual  overall_cond  \
# 892         Norm      1Fam      1Story             6             5
# 1219        Norm      1Fam      1Story             7             5
#
#       year_built  year_remod/add roof_style roof_matl exterior_1st  \
# 892         1964            1964      Gable   CompShg      HdBoard
# 1219        1990            1990      Gable   CompShg      HdBoard
#
#      exterior_2nd mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation  \
# 892       Plywood      BrkFace         272.0         TA         TA     CBlock
# 1219      HdBoard         None           0.0         TA         TA      PConc
#
#      bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1  \
# 892         TA        TA            No            BLQ         490.0
# 1219        Gd        TA            No            Unf           0.0
#
#      bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf heating  \
# 892             Unf           0.0        935.0         1425.0    GasA
# 1219            Unf           0.0       1424.0         1424.0    GasA
#
#      heating_qc central_air electrical  1st_flr_sf  2nd_flr_sf  \
# 892          Gd           Y      SBrkr        1425           0
# 1219         Ex           Y      SBrkr        1442           0
#
#       low_qual_fin_sf  gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  \
# 892                 0         1425             0.0             0.0          2
# 1219                0         1442             0.0             0.0          2
#
#       half_bath  bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd  \
# 892           0              3              1           TA              7
# 1219          0              3              1           TA              5
#
#      functional  fireplaces garage_type garage_yr_blt garage_finish  \
# 892         Typ           1      Attchd          1964           RFn
# 1219        Typ           0      Attchd          1990           RFn
#
#       garage_cars  garage_area garage_qual garage_cond paved_drive  \
# 892           2.0        576.0          TA          TA           Y
# 1219          2.0        500.0          TA          TA           Y
#
#       wood_deck_sf  open_porch_sf  enclosed_porch  3ssn_porch  screen_porch  \
# 892              0              0               0         407             0
# 1219             0             34               0         508             0
#
#       pool_area  misc_val  mo_sold  yr_sold sale_type  saleprice
# 892           0         0        7     2008       WD      180500
# 1219          0         0        5     2009       WD      180500

# %%
#Drop and check
train.drop(train[train['3ssn_porch'] > 400].index, inplace = True)
train[(train['3ssn_porch'] > 400)]
# Out:
# Empty DataFrame
# Columns: [ms_subclass, ms_zoning, lot_frontage, lot_area, street, lot_shape, land_contour, utilities, lot_config, land_slope, neighborhood, condition_1, condition_2, bldg_type, house_style, overall_qual, overall_cond, year_built, year_remod/add, roof_style, roof_matl, exterior_1st, exterior_2nd, mas_vnr_type, mas_vnr_area, exter_qual, exter_cond, foundation, bsmt_qual, bsmt_cond, bsmt_exposure, bsmtfin_type_1, bsmtfin_sf_1, bsmtfin_type_2, bsmtfin_sf_2, bsmt_unf_sf, total_bsmt_sf, heating, heating_qc, central_air, electrical, 1st_flr_sf, 2nd_flr_sf, low_qual_fin_sf, gr_liv_area, bsmt_full_bath, bsmt_half_bath, full_bath, half_bath, bedroom_abvgr, kitchen_abvgr, kitchen_qual, totrms_abvgrd, functional, fireplaces, garage_type, garage_yr_blt, garage_finish, garage_cars, garage_area, garage_qual, garage_cond, paved_drive, wood_deck_sf, open_porch_sf, enclosed_porch, 3ssn_porch, screen_porch, pool_area, misc_val, mo_sold, yr_sold, sale_type, saleprice]
# Index: []

# %%
#misc_val: 2 above 10k
train[(train['misc_val'] > 10000)]
# Out:
#     ms_subclass ms_zoning  lot_frontage  lot_area street lot_shape  \
# 304          20        RL          81.0     14267   Pave       IR1
#
#     land_contour utilities lot_config land_slope neighborhood condition_1  \
# 304          Lvl    AllPub     Corner        Gtl        NAmes        Norm
#
#     condition_2 bldg_type house_style  overall_qual  overall_cond  year_built  \
# 304        Norm      1Fam      1Story             6             6        1958
#
#      year_remod/add roof_style roof_matl exterior_1st exterior_2nd  \
# 304            1958        Hip   CompShg      Wd Sdng      Wd Sdng
#
#     mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation bsmt_qual  \
# 304      BrkFace         108.0         TA         TA     CBlock        TA
#
#     bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1 bsmtfin_type_2  \
# 304        TA            No            ALQ         923.0            Unf
#
#      bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf heating heating_qc central_air  \
# 304           0.0        406.0         1329.0    GasA         TA           Y
#
#     electrical  1st_flr_sf  2nd_flr_sf  low_qual_fin_sf  gr_liv_area  \
# 304      SBrkr        1329           0                0         1329
#
#      bsmt_full_bath  bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  \
# 304             0.0             0.0          1          1              3
#
#      kitchen_abvgr kitchen_qual  totrms_abvgrd functional  fireplaces  \
# 304              1           Gd              6        Typ           0
#
#     garage_type garage_yr_blt garage_finish  garage_cars  garage_area  \
# 304      Attchd          1958           Unf          1.0        312.0
#
#     garage_qual garage_cond paved_drive  wood_deck_sf  open_porch_sf  \
# 304          TA          TA           Y           393             36
#
#      enclosed_porch  3ssn_porch  screen_porch  pool_area  misc_val  mo_sold  \
# 304               0           0             0          0     12500        6
#
#      yr_sold sale_type  saleprice
# 304     2010       WD      172000

# %%
#Drop and check
train.drop(train[train['misc_val'] > 10000].index, inplace = True)
train[(train['misc_val'] > 10000)]
# Out:
# Empty DataFrame
# Columns: [ms_subclass, ms_zoning, lot_frontage, lot_area, street, lot_shape, land_contour, utilities, lot_config, land_slope, neighborhood, condition_1, condition_2, bldg_type, house_style, overall_qual, overall_cond, year_built, year_remod/add, roof_style, roof_matl, exterior_1st, exterior_2nd, mas_vnr_type, mas_vnr_area, exter_qual, exter_cond, foundation, bsmt_qual, bsmt_cond, bsmt_exposure, bsmtfin_type_1, bsmtfin_sf_1, bsmtfin_type_2, bsmtfin_sf_2, bsmt_unf_sf, total_bsmt_sf, heating, heating_qc, central_air, electrical, 1st_flr_sf, 2nd_flr_sf, low_qual_fin_sf, gr_liv_area, bsmt_full_bath, bsmt_half_bath, full_bath, half_bath, bedroom_abvgr, kitchen_abvgr, kitchen_qual, totrms_abvgrd, functional, fireplaces, garage_type, garage_yr_blt, garage_finish, garage_cars, garage_area, garage_qual, garage_cond, paved_drive, wood_deck_sf, open_porch_sf, enclosed_porch, 3ssn_porch, screen_porch, pool_area, misc_val, mo_sold, yr_sold, sale_type, saleprice]
# Index: []

# %%
train.shape
# Out:
# (2043, 74)

# %%
#split data columns into numerical and categorical
train_num = train.select_dtypes(exclude='object')
train_cat = train.select_dtypes(include='object')

#Put the columns into a list
list_num = list(train_num)
list_cat = list(train_cat)

#Check the shapes
train.shape, train_num.shape, train_cat.shape
# Out:
# ((2043, 74), (2043, 35), (2043, 39))

# %% [markdown]
# Pick out features that are highly correlated with each other (benchmark as > 0.8). Drop one of them to avoid multi collinearity.
#
# 1. 'yr_sold' and 'id': drop 'yr_sold' as 'id' has higher correlation with 'saleprice'
# 2. '1st_flr_sf' and 'total_bsmt_sf': drop '1st_flr_sf' as 'total_bsmt_sf' has higher correlation with 'saleprice'
# 3. 'totrms_abvgrd' and 'gr_liv_area': drop 'totrms_abvgrd' as 'gr_liv_area' has higher correlation with 'saleprice'
# 4. 'garage_area' and 'garage_cars': drop 'garage_cars' as 'garage_area' has higher correlation with 'saleprice'
#
# Note: also drop pid - it acts as an unique identifier (similar to id)
#
# columns to drop = ['yr_sold', '1st_flr_sf', 'totrms_abvgrd', 'garage_cars', 'pid']

# %%
num_col_to_drop = ['yr_sold', '1st_flr_sf', 'totrms_abvgrd', 'garage_cars']

#Drop columns from train and test
train = train.drop(num_col_to_drop, axis=1)
#test = test.drop(num_col_to_drop, axis=1)

#Drop from train_num too
train_num = train_num.drop(num_col_to_drop, axis=1)
list_num = list(train_num)

# %%
#Check the shape of train 
train.shape, train_num.shape, train_cat.shape
#confirmed that 5 columns are dropped
# Out:
# ((2043, 70), (2043, 31), (2043, 39))

# %%
#Plot categorical data
#Look at distribution of categorical data in their own category
subplots(train_cat,list_cat);

# %%
#From categorical data, split into Ordinal/Nominal

train_cat_ordinal = ['lot_shape','utilities','land_slope','exter_qual',
       'exter_cond','bsmt_qual', 'bsmt_cond', 'bsmt_exposure',
       'bsmtfin_type_1', 'bsmtfin_type_2','heating_qc','electrical','kitchen_qual', 'functional']

train_cat_nominal = ['ms_zoning', 'street','land_contour','lot_config','neighborhood', 'condition_1',
       'condition_2', 'bldg_type', 'house_style','roof_style', 'roof_matl',
       'exterior_1st', 'exterior_2nd', 'mas_vnr_type', 'foundation','heating','central_air','garage_type','garage_yr_blt','garage_finish', 'garage_qual',
       'garage_cond', 'paved_drive','sale_type']

# %%
#For ordinal data, change from categories to numerical

train["lot_shape"].replace({"IR3": 1, "IR2":2, "IR1":3, "Reg":4}, inplace = True)
train["utilities"].replace({"AllPub": 4, "NoSewr":3, "NoSeWa":2, "ELO":1}, inplace = True)
train["land_slope"].replace({"Sev": 3, "Mod":2, "Gtl":1}, inplace = True)
train["exter_qual"].replace({"Ex": 5, "Gd":4, "TA":3, "Fa":2, "Po":1}, inplace = True)
train["exter_cond"].replace({"Ex": 5, "Gd":4, "TA":3, "Fa":2, "Po":1}, inplace = True)
train["bsmt_qual"].replace({"Ex": 5, "Gd":4, "TA":3, "Fa":2, "Po":1, "NA":0}, inplace = True)
train["bsmt_cond"].replace({"Ex": 5, "Gd":4, "TA":3, "Fa":2, "Po":1, "NA":0}, inplace = True)
train['bsmt_exposure'].replace({"Gd": 4, "Av":3, "Mn":2, "No":1, "NA":0}, inplace = True)
train["bsmtfin_type_1"].replace({"GLQ": 6, "ALQ": 5, "BLQ": 4, "Rec":3, "LwQ":2, "Unf":1, "NA":0}, inplace = True)
train["bsmtfin_type_2"].replace({"GLQ": 6, "ALQ": 5, "BLQ": 4, "Rec":3, "LwQ":2, "Unf":1, "NA":0}, inplace = True)
train["heating_qc"].replace({"Ex": 5, "Gd":4, "TA":3, "Fa":2, "Po":1}, inplace = True)
train["electrical"].replace({"SBrkr": 5, "FuseA":4, "FuseF":3, "FuseP":2, "Mix":1}, inplace = True)
train["kitchen_qual"].replace({"Ex": 5, "Gd":4, "TA":3, "Fa":2, "Po":1}, inplace = True)
train["functional"].replace({"Typ": 8, "Min1": 7, "Min2": 6, "Mod":5, "Maj1":4, "Maj2":3, "Sev": 2, "Sal":1}, inplace = True)

# %%
#Plot categorical data against Sale Price; boxplots
#do the plotting after change ordinal to numerical, it helps to understand the trends

#For a quick view
fig, ax = plt.subplots(nrows=20, ncols=2, figsize=(20,90)) 
#fig, ax = plt.subplots(nrows=14, ncols=3, figsize=(12,30)) 

ax = ax.ravel() 
for i, column in enumerate(list_cat): 
    sns.boxplot(x=column,y='saleprice',data=train, ax=ax[i], showfliers=False)

fig.tight_layout(pad=2)

# %% [markdown]
# Observations:
# - ms_subclass: 60 and 120 have higher saleprice
# - ms_zoning: Floating Village Residential has higher saleprice
# - street: paved has higher sale price
# - lot_shape: the more regular, the higher the saleprice
# - land_contour: hillside has higher saleprice
# - land_slope: severe slope has higher saleprice
# - roof_matl: Wood Shingles have higher saleprice
# - basement factors affect price (generally, better quality, better price)
# - new house sell for higher price

# %%
train.shape, train_num.shape, train_cat.shape
# Out:
# ((2043, 70), (2043, 31), (2043, 39))

# %%
#save the file as train.csv
os.chdir("C:/Users/annitan/Desktop/GA/DSIF-SG-7 - Copy/Project_2/data")
train.to_csv('train_cleaned.csv')
